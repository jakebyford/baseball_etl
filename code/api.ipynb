# %%
import requests
import json
from pandas import DataFrame, Series
import pandas as pd

# MLB DATA API Documentation - https://appac.github.io/mlb-data-api-docs/

# %%
full_mookie_url = "http://lookup-service-prod.mlb.com/json/named.search_player_all.bam?sport_code=%27mlb%27&active_sw=%27Y%27&name_part=%27mookie%25%27"

# %%
resp = requests.get(full_mookie_url)
resp
# Out:
# <Response [200]>

# %%
mookie_json = resp.json()
mookie_json
# Out:
# {'search_player_all': {'copyRight': ' Copyright 2022 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt  ',
#   'queryResults': {'created': '2022-06-23T17:24:42',
#    'totalSize': '1',
#    'row': {'position': 'RF',
#     'birth_country': 'USA',
#     'weight': '180',
#     'birth_state': 'TN',
#     'name_display_first_last': 'Mookie Betts',
#     'college': '',
#     'height_inches': '9',
#     'name_display_roster': 'Betts',
#     'sport_code': 'mlb',
#     'bats': 'R',
#     'name_first': 'Mookie',
#     'team_code': 'lan',
#     'birth_city': 'Nashville',
#     'height_feet': '5',
#     'pro_debut_date': '2014-06-29T00:00:00',
#     'team_full': 'Los Angeles Dodgers',
#     'team_abbrev': 'LAD',
#     'birth_date': '1992-10-07T00:00:00',
#     'throws': 'R',
#     'league': 'NL',
#     'name_display_last_first': 'Betts, Mookie',
#     'position_id': '9',
#     'high_school': 'John Overton, Nashville, TN',
#     'name_use': 'Mookie',
#     'player_id': '605141',
#     'name_last': 'Betts',
#     'team_id': '119',
#     'service_years': '',
#     'active_sw': 'Y'}}}}

# %%
mookie_json['search_player_all']['queryResults']['row']
# Out:
# {'position': 'RF',
#  'birth_country': 'USA',
#  'weight': '180',
#  'birth_state': 'TN',
#  'name_display_first_last': 'Mookie Betts',
#  'college': '',
#  'height_inches': '9',
#  'name_display_roster': 'Betts',
#  'sport_code': 'mlb',
#  'bats': 'R',
#  'name_first': 'Mookie',
#  'team_code': 'lan',
#  'birth_city': 'Nashville',
#  'height_feet': '5',
#  'pro_debut_date': '2014-06-29T00:00:00',
#  'team_full': 'Los Angeles Dodgers',
#  'team_abbrev': 'LAD',
#  'birth_date': '1992-10-07T00:00:00',
#  'throws': 'R',
#  'league': 'NL',
#  'name_display_last_first': 'Betts, Mookie',
#  'position_id': '9',
#  'high_school': 'John Overton, Nashville, TN',
#  'name_use': 'Mookie',
#  'player_id': '605141',
#  'name_last': 'Betts',
#  'team_id': '119',
#  'service_years': '',
#  'active_sw': 'Y'}

# %% [markdown]
# # Restricting which variables you get back with ```col_in``` and ```col_ex```

# %% [markdown]
# #### to do that we add ```&search_player_all.col_ex={variable_we_don't_want}```
# #### or ```&search_player_all.col_ex={variable_we_want}```
# To add more then one variable seperate with a comma AND no space

# %%
# col_in
mookie_url2 = "http://lookup-service-prod.mlb.com/json/named.search_player_all.bam?sport_code=%27mlb%27&active_sw=%27Y%27&name_part=%27mookie%25%27&search_player_all.col_in=player_id,name_display_first_last,team_full,position,bats,throws"

# %%
resp2 = requests.get(mookie_url2)

# %%
mookie_json2 = resp2.json()
mookie_json2
# Out:
# {'search_player_all': {'copyRight': ' Copyright 2022 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt  ',
#   'queryResults': {'created': '2022-06-23T17:24:42',
#    'totalSize': '1',
#    'row': {'position': 'RF',
#     'bats': 'R',
#     'throws': 'R',
#     'name_display_first_last': 'Mookie Betts',
#     'player_id': '605141',
#     'team_full': 'Los Angeles Dodgers'}}}}

# %%
# col_ex
mookie_url3 = "http://lookup-service-prod.mlb.com/json/named.search_player_all.bam?sport_code=%27mlb%27&active_sw=%27Y%27&name_part=%27mookie%25%27&search_player_all.col_ex=player_id,name_display_first_last,team_full,position,bats,throws, position_id,name_use,name_last,team_id,name_display_roster,sport_code,name_first"

# %%
resp3 = requests.get(mookie_url3)
mookie_json3 = resp3.json()
mookie_json3
# Out:
# {'search_player_all': {'copyRight': ' Copyright 2022 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt  ',
#   'queryResults': {'created': '2022-06-23T17:24:42',
#    'totalSize': '1',
#    'row': {'birth_country': 'USA',
#     'weight': '180',
#     'birth_state': 'TN',
#     'team_abbrev': 'LAD',
#     'birth_date': '1992-10-07T00:00:00',
#     'college': '',
#     'height_inches': '9',
#     'league': 'NL',
#     'name_display_last_first': 'Betts, Mookie',
#     'position_id': '9',
#     'high_school': 'John Overton, Nashville, TN',
#     'team_code': 'lan',
#     'height_feet': '5',
#     'birth_city': 'Nashville',
#     'pro_debut_date': '2014-06-29T00:00:00',
#     'service_years': '',
#     'active_sw': 'Y'}}}}

# %% [markdown]
# ### If we look at some of the other urls in the documentation we'll notice they all start with the same thing. To make things easier we'll assign it to a constant variable

# %%
MLB_URL = 'http://lookup-service-prod.mlb.com/json/'

# %% [markdown]
# Now we can work with each endpoint separately

# %%
mookie_endpoint = 'named.search_player_all.bam?sport_code=%27mlb%27&active_sw=%27Y%27&name_part=%27mookie%25%27'

requests.get(MLB_URL + mookie_endpoint)
# Out:
# <Response [200]>

# %% [markdown]
# That's a bit easier but that endpoint is a bit overwhelming. Let's put it in a function. This will make it easier to think about

# %%
def player_search(to_search):
    search_endpoint = f'/named.search_player_all.bam?sport_code=%27mlb%27&active_sw=%27Y%27&name_part=%27{to_search}%25%27&search_player_all.col_in=player_id,name_display_first_last,team_full,position,bats,throws,team_id'
    
    resp = requests.get(MLB_URL + search_endpoint)
    try:
        return resp.json()['search_player_all']['queryResults']['row']
    except KeyError:
        print("ERROR: Not a player")

# %%
# Note how we're putting whatever is in ```to_search``` inside our URL with f strings
yelich = player_search('yelich')
yelich
# Out:
# {'position': 'LF',
#  'bats': 'L',
#  'throws': 'R',
#  'name_display_first_last': 'Christian Yelich',
#  'player_id': '592885',
#  'team_id': '158',
#  'team_full': 'Milwaukee Brewers'}

# %% [markdown]
# Always good to try out a few use cases and make sure it works properly. What if we put a players full name?

# %%
aaron_judge = player_search('aaron judge')
aaron_judge
# Out:
# {'position': 'RF',
#  'bats': 'R',
#  'throws': 'R',
#  'name_display_first_last': 'Aaron Judge',
#  'player_id': '592450',
#  'team_id': '147',
#  'team_full': 'New York Yankees'}

# %%
mike_trout = player_search('mike trout')
mike_trout
# Out:
# {'position': 'CF',
#  'bats': 'R',
#  'throws': 'R',
#  'name_display_first_last': 'Mike Trout',
#  'player_id': '545361',
#  'team_id': '108',
#  'team_full': 'Los Angeles Angels'}

# %%
bellingers = player_search('bellinger')
bellingers
# Out:
# [{'position': '1B',
#   'bats': 'R',
#   'throws': 'R',
#   'name_display_first_last': 'Clay Bellinger',
#   'player_id': '150083',
#   'team_id': '108',
#   'team_full': 'Los Angeles Angels'},
#  {'position': 'CF',
#   'bats': 'L',
#   'throws': 'L',
#   'name_display_first_last': 'Cody Bellinger',
#   'player_id': '641355',
#   'team_id': '119',
#   'team_full': 'Los Angeles Dodgers'}]

# %%
pete_alonso = player_search('pete alonso')
pete_alonso
# Out:
# {'position': '1B',
#  'bats': 'R',
#  'throws': 'R',
#  'name_display_first_last': 'Pete Alonso',
#  'player_id': '624413',
#  'team_id': '121',
#  'team_full': 'New York Mets'}

# %%
not_a_player = player_search('askf')
not_a_player
# Out:
# ERROR: Not a player

# %% [markdown]
# # Hitting and Pitching Stats

# %% [markdown]
# There are endpoints for hitting and pitching stats, both by season and career. All endpoints take a numeric player id. The specific season htting and pitcher stas also take a year

# %%
# Get the current Roster of the Brewers 
brewers_url = MLB_URL + f'/named.roster_40.bam?team_id=%27158%27'

brewers_resp = requests.get(brewers_url)

brewers_dict = json.loads(brewers_resp.text)['roster_40']['queryResults']['row']
brewers_dict
# Out:
# [{'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-05-22T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Adames, Willy',
#   'name_display_first_last': 'Willy Adames',
#   'birth_date': '1995-09-02T00:00:00',
#   'height_inches': '0',
#   'team_id': '158',
#   'name_last': 'Adames',
#   'bats': 'R',
#   'player_id': '642715',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '27',
#   'starter_sw': 'N',
#   'start_date': '2021-05-21T00:00:00',
#   'name_display_last_first': 'Adames, Willy',
#   'name_first': 'Willy',
#   'name_use': 'Willy',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Menlo, CA',
#   'end_date': '',
#   'pro_debut_date': '2022-06-01T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Alexander, Jason',
#   'name_display_first_last': 'Jason Alexander',
#   'birth_date': '1993-03-01T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Alexander',
#   'bats': 'R',
#   'player_id': '669920',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '41',
#   'starter_sw': 'N',
#   'start_date': '2022-06-01T00:00:00',
#   'name_display_last_first': 'Alexander, Jason',
#   'name_first': 'Jason',
#   'name_use': 'Jason',
#   'weight': '200',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Crowder JC, MO',
#   'end_date': '',
#   'pro_debut_date': '2021-06-30T00:00:00',
#   'status_code': 'D15',
#   'name_full': 'Ashby, Aaron',
#   'name_display_first_last': 'Aaron Ashby',
#   'birth_date': '1998-05-24T00:00:00',
#   'height_inches': '2',
#   'team_id': '158',
#   'name_last': 'Ashby',
#   'bats': 'R',
#   'player_id': '676879',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '26',
#   'starter_sw': 'N',
#   'start_date': '2021-06-30T00:00:00',
#   'name_display_last_first': 'Ashby, Aaron',
#   'name_first': 'Aaron',
#   'name_use': 'Aaron',
#   'weight': '181',
#   'throws': 'L',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Cal State Chico',
#   'end_date': '',
#   'pro_debut_date': '2022-06-03T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Barker, Luke',
#   'name_display_first_last': 'Luke Barker',
#   'birth_date': '1992-03-11T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Barker',
#   'bats': 'R',
#   'player_id': '673316',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '49',
#   'starter_sw': 'N',
#   'start_date': '2022-05-30T00:00:00',
#   'name_display_last_first': 'Barker, Luke',
#   'name_first': 'Luke',
#   'name_use': 'Luke',
#   'weight': '230',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Southern California',
#   'end_date': '',
#   'pro_debut_date': '2012-06-10T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Boxberger, Brad',
#   'name_display_first_last': 'Brad Boxberger',
#   'birth_date': '1988-05-27T00:00:00',
#   'height_inches': '10',
#   'team_id': '158',
#   'name_last': 'Boxberger',
#   'bats': 'R',
#   'player_id': '502202',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '45',
#   'starter_sw': 'N',
#   'start_date': '2022-03-13T00:00:00',
#   'name_display_last_first': 'Boxberger, Brad',
#   'name_first': 'Bradley',
#   'name_use': 'Brad',
#   'weight': '211',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '5'},
#  {'college': 'Oakland',
#   'end_date': '',
#   'pro_debut_date': '2019-06-23T00:00:00',
#   'status_code': 'D10',
#   'name_full': 'Brosseau, Mike',
#   'name_display_first_last': 'Mike Brosseau',
#   'birth_date': '1994-03-15T00:00:00',
#   'height_inches': '10',
#   'team_id': '158',
#   'name_last': 'Brosseau',
#   'bats': 'R',
#   'player_id': '670712',
#   'position_txt': '3B',
#   'primary_position': '5',
#   'jersey_number': '20',
#   'starter_sw': 'N',
#   'start_date': '2021-11-13T00:00:00',
#   'name_display_last_first': 'Brosseau, Mike',
#   'name_first': 'Michael',
#   'name_use': 'Mike',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '5'},
#  {'college': "St. Mary's, CA",
#   'end_date': '',
#   'pro_debut_date': '2018-07-10T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Burnes, Corbin',
#   'name_display_first_last': 'Corbin Burnes',
#   'birth_date': '1994-10-22T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Burnes',
#   'bats': 'R',
#   'player_id': '669203',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '39',
#   'starter_sw': 'N',
#   'start_date': '2018-07-08T00:00:00',
#   'name_display_last_first': 'Burnes, Corbin',
#   'name_first': 'Corbin',
#   'name_use': 'Corbin',
#   'weight': '225',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Miami Dade CC',
#   'end_date': '',
#   'pro_debut_date': '2017-06-28T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Caratini, Victor',
#   'name_display_first_last': 'Victor Caratini',
#   'birth_date': '1993-08-17T00:00:00',
#   'height_inches': '1',
#   'team_id': '158',
#   'name_last': 'Caratini',
#   'bats': 'S',
#   'player_id': '605170',
#   'position_txt': 'C',
#   'primary_position': '2',
#   'jersey_number': '7',
#   'starter_sw': 'N',
#   'start_date': '2022-04-06T00:00:00',
#   'name_display_last_first': 'Caratini, Victor',
#   'name_first': 'Victor',
#   'name_use': 'Victor',
#   'weight': '215',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Central Arkansas',
#   'end_date': '',
#   'pro_debut_date': '2018-09-05T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Davis, Jonathan',
#   'name_display_first_last': 'Jonathan Davis',
#   'birth_date': '1992-05-12T00:00:00',
#   'height_inches': '8',
#   'team_id': '158',
#   'name_last': 'Davis',
#   'bats': 'R',
#   'player_id': '641505',
#   'position_txt': 'CF',
#   'primary_position': '8',
#   'jersey_number': '3',
#   'starter_sw': 'N',
#   'start_date': '2022-06-18T00:00:00',
#   'name_display_last_first': 'Davis, Jonathan',
#   'name_first': 'Jonathan',
#   'name_use': 'Jonathan',
#   'weight': '190',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2021-05-01T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Feliciano, Mario',
#   'name_display_first_last': 'Mario Feliciano',
#   'birth_date': '1998-11-20T00:00:00',
#   'height_inches': '1',
#   'team_id': '158',
#   'name_last': 'Feliciano',
#   'bats': 'R',
#   'player_id': '666128',
#   'position_txt': 'C',
#   'primary_position': '2',
#   'jersey_number': '0',
#   'starter_sw': 'N',
#   'start_date': '2020-11-20T00:00:00',
#   'name_display_last_first': 'Feliciano, Mario',
#   'name_first': 'Mario',
#   'name_use': 'Mario',
#   'weight': '200',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Oral Roberts',
#   'end_date': '',
#   'pro_debut_date': '2015-05-30T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Gonzalez, Chi Chi',
#   'name_display_first_last': 'Chi Chi Gonzalez',
#   'birth_date': '1992-01-15T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Gonzalez',
#   'bats': 'R',
#   'player_id': '592346',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '21',
#   'starter_sw': 'N',
#   'start_date': '2022-06-14T00:00:00',
#   'name_display_last_first': 'Gonzalez, Chi Chi',
#   'name_first': 'Alexander',
#   'name_use': 'Chi Chi',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Kentucky',
#   'end_date': '',
#   'pro_debut_date': '2015-06-14T00:00:00',
#   'status_code': 'D15',
#   'name_full': 'Gott, Trevor',
#   'name_display_first_last': 'Trevor Gott',
#   'birth_date': '1992-08-26T00:00:00',
#   'height_inches': '10',
#   'team_id': '158',
#   'name_last': 'Gott',
#   'bats': 'R',
#   'player_id': '641627',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '48',
#   'starter_sw': 'N',
#   'start_date': '2021-11-03T00:00:00',
#   'name_display_last_first': 'Gott, Trevor',
#   'name_first': 'Trevor',
#   'name_use': 'Trevor',
#   'weight': '182',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2016-08-11T00:00:00',
#   'status_code': 'D15',
#   'name_full': 'Gustave, Jandel',
#   'name_display_first_last': 'Jandel Gustave',
#   'birth_date': '1992-10-12T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Gustave',
#   'bats': 'R',
#   'player_id': '594311',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '31',
#   'starter_sw': 'N',
#   'start_date': '2021-07-07T00:00:00',
#   'name_display_last_first': 'Gustave, Jandel',
#   'name_first': 'Jandel',
#   'name_use': 'Jandel',
#   'weight': '220',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2017-06-10T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Hader, Josh',
#   'name_display_first_last': 'Josh Hader',
#   'birth_date': '1994-04-07T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Hader',
#   'bats': 'L',
#   'player_id': '623352',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '71',
#   'starter_sw': 'N',
#   'start_date': '2016-11-18T00:00:00',
#   'name_display_last_first': 'Hader, Josh',
#   'name_first': 'Josh',
#   'name_use': 'Josh',
#   'weight': '180',
#   'throws': 'L',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'UC Irvine',
#   'end_date': '',
#   'pro_debut_date': '2019-05-14T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Hiura, Keston',
#   'name_display_first_last': 'Keston Hiura',
#   'birth_date': '1996-08-02T00:00:00',
#   'height_inches': '0',
#   'team_id': '158',
#   'name_last': 'Hiura',
#   'bats': 'R',
#   'player_id': '669374',
#   'position_txt': '1B',
#   'primary_position': '3',
#   'jersey_number': '18',
#   'starter_sw': 'N',
#   'start_date': '2019-05-14T00:00:00',
#   'name_display_last_first': 'Hiura, Keston',
#   'name_first': 'Keston',
#   'name_use': 'Keston',
#   'weight': '202',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2015-09-26T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Houser, Adrian',
#   'name_display_first_last': 'Adrian Houser',
#   'birth_date': '1993-02-02T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Houser',
#   'bats': 'R',
#   'player_id': '605288',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '37',
#   'starter_sw': 'N',
#   'start_date': '2015-09-22T00:00:00',
#   'name_display_last_first': 'Houser, Adrian',
#   'name_first': 'Adrian',
#   'name_use': 'Adrian',
#   'weight': '222',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2019-04-07T00:00:00',
#   'status_code': 'D10',
#   'name_full': 'Jackson, Alex',
#   'name_display_first_last': 'Alex Jackson',
#   'birth_date': '1995-12-25T00:00:00',
#   'height_inches': '2',
#   'team_id': '158',
#   'name_last': 'Jackson',
#   'bats': 'R',
#   'player_id': '656577',
#   'position_txt': 'C',
#   'primary_position': '2',
#   'jersey_number': '5',
#   'starter_sw': 'N',
#   'start_date': '2022-04-07T00:00:00',
#   'name_display_last_first': 'Jackson, Alex',
#   'name_first': 'Alex',
#   'name_use': 'Alex',
#   'weight': '215',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'North Carolina',
#   'end_date': '',
#   'pro_debut_date': '2019-07-02T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Kelley, Trevor',
#   'name_display_first_last': 'Trevor Kelley',
#   'birth_date': '1992-10-20T00:00:00',
#   'height_inches': '2',
#   'team_id': '158',
#   'name_last': 'Kelley',
#   'bats': 'R',
#   'player_id': '665001',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '57',
#   'starter_sw': 'N',
#   'start_date': '2022-05-17T00:00:00',
#   'name_display_last_first': 'Kelley, Trevor',
#   'name_first': 'Trevor',
#   'name_use': 'Trevor',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Kent state',
#   'end_date': '',
#   'pro_debut_date': '2018-04-24T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Lauer, Eric',
#   'name_display_first_last': 'Eric Lauer',
#   'birth_date': '1995-06-03T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Lauer',
#   'bats': 'R',
#   'player_id': '641778',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '52',
#   'starter_sw': 'N',
#   'start_date': '2019-11-27T00:00:00',
#   'name_display_last_first': 'Lauer, Eric',
#   'name_first': 'Eric',
#   'name_use': 'Eric',
#   'weight': '228',
#   'throws': 'L',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Cal Poly San Luis Obispo',
#   'end_date': '',
#   'pro_debut_date': '2020-08-04T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Mathias, Mark',
#   'name_display_first_last': 'Mark Mathias',
#   'birth_date': '1994-08-02T00:00:00',
#   'height_inches': '0',
#   'team_id': '158',
#   'name_last': 'Mathias',
#   'bats': 'R',
#   'player_id': '664029',
#   'position_txt': '2B',
#   'primary_position': '4',
#   'jersey_number': '13',
#   'starter_sw': 'N',
#   'start_date': '2022-05-24T00:00:00',
#   'name_display_last_first': 'Mathias, Mark',
#   'name_first': 'Mark',
#   'name_use': 'Mark',
#   'weight': '200',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2009-06-04T00:00:00',
#   'status_code': 'A',
#   'name_full': 'McCutchen, Andrew',
#   'name_display_first_last': 'Andrew McCutchen',
#   'birth_date': '1986-10-10T00:00:00',
#   'height_inches': '11',
#   'team_id': '158',
#   'name_last': 'McCutchen',
#   'bats': 'R',
#   'player_id': '457705',
#   'position_txt': 'LF',
#   'primary_position': '7',
#   'jersey_number': '24',
#   'starter_sw': 'N',
#   'start_date': '2022-03-16T00:00:00',
#   'name_display_last_first': 'McCutchen, Andrew',
#   'name_first': 'Andrew',
#   'name_use': 'Andrew',
#   'weight': '195',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '5'},
#  {'college': 'Texas',
#   'end_date': '',
#   'pro_debut_date': '2017-06-24T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Milner, Hoby',
#   'name_display_first_last': 'Hoby Milner',
#   'birth_date': '1991-01-13T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Milner',
#   'bats': 'L',
#   'player_id': '571948',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '55',
#   'starter_sw': 'N',
#   'start_date': '2021-05-15T00:00:00',
#   'name_display_last_first': 'Milner, Hoby',
#   'name_first': 'Hoby',
#   'name_use': 'Hoby',
#   'weight': '175',
#   'throws': 'L',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2016-07-17T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Narvaez, Omar',
#   'name_display_first_last': 'Omar Narvaez',
#   'birth_date': '1992-02-10T00:00:00',
#   'height_inches': '11',
#   'team_id': '158',
#   'name_last': 'Narvaez',
#   'bats': 'L',
#   'player_id': '553882',
#   'position_txt': 'C',
#   'primary_position': '2',
#   'jersey_number': '10',
#   'starter_sw': 'N',
#   'start_date': '2019-12-05T00:00:00',
#   'name_display_last_first': 'Narvaez, Omar',
#   'name_first': 'Omar',
#   'name_use': 'Omar',
#   'weight': '220',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2020-08-18T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Perdomo, Angel',
#   'name_display_first_last': 'Angel Perdomo',
#   'birth_date': '1994-05-07T00:00:00',
#   'height_inches': '8',
#   'team_id': '158',
#   'name_last': 'Perdomo',
#   'bats': 'L',
#   'player_id': '622780',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '47',
#   'starter_sw': 'N',
#   'start_date': '2019-11-04T00:00:00',
#   'name_display_last_first': 'Perdomo, Angel',
#   'name_first': 'Angel',
#   'name_use': 'Angel',
#   'weight': '265',
#   'throws': 'L',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2016-04-04T00:00:00',
#   'status_code': 'D15',
#   'name_full': 'Perdomo, Luis',
#   'name_display_first_last': 'Luis Perdomo',
#   'birth_date': '1993-05-09T00:00:00',
#   'height_inches': '2',
#   'team_id': '158',
#   'name_last': 'Perdomo',
#   'bats': 'R',
#   'player_id': '606131',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '46',
#   'starter_sw': 'N',
#   'start_date': '2022-05-06T00:00:00',
#   'name_display_last_first': 'Perdomo, Luis',
#   'name_first': 'Luis',
#   'name_use': 'Luis',
#   'weight': '201',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'McNeese State',
#   'end_date': '',
#   'pro_debut_date': '2014-04-25T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Peterson, Jace',
#   'name_display_first_last': 'Jace Peterson',
#   'birth_date': '1990-05-09T00:00:00',
#   'height_inches': '0',
#   'team_id': '158',
#   'name_last': 'Peterson',
#   'bats': 'L',
#   'player_id': '607054',
#   'position_txt': '3B',
#   'primary_position': '5',
#   'jersey_number': '14',
#   'starter_sw': 'N',
#   'start_date': '2021-06-08T00:00:00',
#   'name_display_last_first': 'Peterson, Jace',
#   'name_first': 'Jace',
#   'name_use': 'Jace',
#   'weight': '215',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Mississippi State',
#   'end_date': '',
#   'pro_debut_date': '2016-09-21T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Renfroe, Hunter',
#   'name_display_first_last': 'Hunter Renfroe',
#   'birth_date': '1992-01-28T00:00:00',
#   'height_inches': '1',
#   'team_id': '158',
#   'name_last': 'Renfroe',
#   'bats': 'R',
#   'player_id': '592669',
#   'position_txt': 'RF',
#   'primary_position': '9',
#   'jersey_number': '12',
#   'starter_sw': 'N',
#   'start_date': '2021-12-01T00:00:00',
#   'name_display_last_first': 'Renfroe, Hunter',
#   'name_first': 'Dustin',
#   'name_use': 'Hunter',
#   'weight': '230',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-09-02T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Reyes, Pablo',
#   'name_display_first_last': 'Pablo Reyes',
#   'birth_date': '1993-09-05T00:00:00',
#   'height_inches': '8',
#   'team_id': '158',
#   'name_last': 'Reyes',
#   'bats': 'R',
#   'player_id': '622569',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '33',
#   'starter_sw': 'N',
#   'start_date': '2021-01-07T00:00:00',
#   'name_display_last_first': 'Reyes, Pablo',
#   'name_first': 'Pablo',
#   'name_use': 'Pablo',
#   'weight': '175',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2021-06-22T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Sanchez, Miguel',
#   'name_display_first_last': 'Miguel Sanchez',
#   'birth_date': '1993-12-31T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Sanchez',
#   'bats': 'R',
#   'player_id': '667376',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '58',
#   'starter_sw': 'N',
#   'start_date': '2021-06-22T00:00:00',
#   'name_display_last_first': 'Sanchez, Miguel',
#   'name_first': 'Miguel',
#   'name_use': 'Miguel',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Mississippi State',
#   'end_date': '',
#   'pro_debut_date': '2022-05-30T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Small, Ethan',
#   'name_display_first_last': 'Ethan Small',
#   'birth_date': '1997-02-14T00:00:00',
#   'height_inches': '4',
#   'team_id': '158',
#   'name_last': 'Small',
#   'bats': 'L',
#   'player_id': '663629',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '43',
#   'starter_sw': 'N',
#   'start_date': '2022-05-30T00:00:00',
#   'name_display_last_first': 'Small, Ethan',
#   'name_first': 'Ethan',
#   'name_use': 'Ethan',
#   'weight': '215',
#   'throws': 'L',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'University of South Florida',
#   'end_date': '',
#   'pro_debut_date': '2022-06-02T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Strzelecki, Peter',
#   'name_display_first_last': 'Peter Strzelecki',
#   'birth_date': '1994-10-24T00:00:00',
#   'height_inches': '2',
#   'team_id': '158',
#   'name_last': 'Strzelecki',
#   'bats': 'R',
#   'player_id': '657265',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '32',
#   'starter_sw': 'N',
#   'start_date': '2022-05-30T00:00:00',
#   'name_display_last_first': 'Strzelecki, Peter',
#   'name_first': 'Peter',
#   'name_use': 'Peter',
#   'weight': '195',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Harvard',
#   'end_date': '',
#   'pro_debut_date': '2016-08-19T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Suter, Brent',
#   'name_display_first_last': 'Brent Suter',
#   'birth_date': '1989-08-29T00:00:00',
#   'height_inches': '4',
#   'team_id': '158',
#   'name_last': 'Suter',
#   'bats': 'L',
#   'player_id': '608718',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '35',
#   'starter_sw': 'N',
#   'start_date': '2016-08-19T00:00:00',
#   'name_display_last_first': 'Suter, Brent',
#   'name_first': 'Brent',
#   'name_use': 'Brent',
#   'weight': '213',
#   'throws': 'L',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2019-09-07T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Taylor, Tyrone',
#   'name_display_first_last': 'Tyrone Taylor',
#   'birth_date': '1994-01-22T00:00:00',
#   'height_inches': '0',
#   'team_id': '158',
#   'name_last': 'Taylor',
#   'bats': 'R',
#   'player_id': '621438',
#   'position_txt': 'CF',
#   'primary_position': '8',
#   'jersey_number': '15',
#   'starter_sw': 'N',
#   'start_date': '2018-10-29T00:00:00',
#   'name_display_last_first': 'Taylor, Tyrone',
#   'name_first': 'Tyrone',
#   'name_use': 'Tyrone',
#   'weight': '194',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-09-05T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Tellez, Rowdy',
#   'name_display_first_last': 'Rowdy Tellez',
#   'birth_date': '1995-03-16T00:00:00',
#   'height_inches': '4',
#   'team_id': '158',
#   'name_last': 'Tellez',
#   'bats': 'L',
#   'player_id': '642133',
#   'position_txt': '1B',
#   'primary_position': '3',
#   'jersey_number': '11',
#   'starter_sw': 'N',
#   'start_date': '2021-07-07T00:00:00',
#   'name_display_last_first': 'Tellez, Rowdy',
#   'name_first': 'Ryan',
#   'name_use': 'Rowdy',
#   'weight': '255',
#   'throws': 'L',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-08-28T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Urias, Luis',
#   'name_display_first_last': 'Luis Urias',
#   'birth_date': '1997-06-03T00:00:00',
#   'height_inches': '9',
#   'team_id': '158',
#   'name_last': 'Urias',
#   'bats': 'R',
#   'player_id': '649966',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '2',
#   'starter_sw': 'N',
#   'start_date': '2019-11-27T00:00:00',
#   'name_display_last_first': 'Urias, Luis',
#   'name_first': 'Luis',
#   'name_use': 'Luis',
#   'weight': '186',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2019-08-07T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Williams, Devin',
#   'name_display_first_last': 'Devin Williams',
#   'birth_date': '1994-09-21T00:00:00',
#   'height_inches': '2',
#   'team_id': '158',
#   'name_last': 'Williams',
#   'bats': 'R',
#   'player_id': '642207',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '38',
#   'starter_sw': 'N',
#   'start_date': '2019-08-05T00:00:00',
#   'name_display_last_first': 'Williams, Devin',
#   'name_first': 'Devin',
#   'name_use': 'Devin',
#   'weight': '200',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': 'Hawaii',
#   'end_date': '',
#   'pro_debut_date': '2013-08-16T00:00:00',
#   'status_code': 'D10',
#   'name_full': 'Wong, Kolten',
#   'name_display_first_last': 'Kolten Wong',
#   'birth_date': '1990-10-10T00:00:00',
#   'height_inches': '7',
#   'team_id': '158',
#   'name_last': 'Wong',
#   'bats': 'L',
#   'player_id': '543939',
#   'position_txt': '2B',
#   'primary_position': '4',
#   'jersey_number': '16',
#   'starter_sw': 'N',
#   'start_date': '2021-02-05T00:00:00',
#   'name_display_last_first': 'Wong, Kolten',
#   'name_first': 'Kolten',
#   'name_use': 'Kolten',
#   'weight': '185',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '5'},
#  {'college': 'Mississippi State',
#   'end_date': '',
#   'pro_debut_date': '2017-08-04T00:00:00',
#   'status_code': 'D15',
#   'name_full': 'Woodruff, Brandon',
#   'name_display_first_last': 'Brandon Woodruff',
#   'birth_date': '1993-02-10T00:00:00',
#   'height_inches': '4',
#   'team_id': '158',
#   'name_last': 'Woodruff',
#   'bats': 'L',
#   'player_id': '605540',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '53',
#   'starter_sw': 'N',
#   'start_date': '2017-03-08T00:00:00',
#   'name_display_last_first': 'Woodruff, Brandon',
#   'name_first': 'Brandon',
#   'name_use': 'Brandon',
#   'weight': '243',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2013-07-23T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Yelich, Christian',
#   'name_display_first_last': 'Christian Yelich',
#   'birth_date': '1991-12-05T00:00:00',
#   'height_inches': '3',
#   'team_id': '158',
#   'name_last': 'Yelich',
#   'bats': 'L',
#   'player_id': '592885',
#   'position_txt': 'LF',
#   'primary_position': '7',
#   'jersey_number': '22',
#   'starter_sw': 'N',
#   'start_date': '2018-01-25T00:00:00',
#   'name_display_last_first': 'Yelich, Christian',
#   'name_first': 'Christian',
#   'name_use': 'Christian',
#   'weight': '195',
#   'throws': 'R',
#   'team_name': 'Milwaukee Brewers',
#   'team_code': 'mil',
#   'team_abbrev': 'MIL',
#   'height_feet': '6'}]

# %%
# same but with the Yankees
yankees_url = MLB_URL + f'/named.roster_40.bam?team_id=%27147%27'

yankees_resp = requests.get(yankees_url)

yankees_dict = json.loads(yankees_resp.text)['roster_40']['queryResults']['row']
yankees_dict
# Out:
# [{'college': '',
#   'end_date': '',
#   'pro_debut_date': '2020-08-08T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Abreu, Albert',
#   'name_display_first_last': 'Albert Abreu',
#   'birth_date': '1995-09-26T00:00:00',
#   'height_inches': '2',
#   'team_id': '147',
#   'name_last': 'Abreu',
#   'bats': 'R',
#   'player_id': '656061',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '',
#   'starter_sw': 'N',
#   'start_date': '2022-06-21T00:00:00',
#   'name_display_last_first': 'Abreu, Albert',
#   'name_first': 'Albert',
#   'name_use': 'Albert',
#   'weight': '190',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2017-06-28T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Andujar, Miguel',
#   'name_display_first_last': 'Miguel Andujar',
#   'birth_date': '1995-03-02T00:00:00',
#   'height_inches': '0',
#   'team_id': '147',
#   'name_last': 'Andujar',
#   'bats': 'R',
#   'player_id': '609280',
#   'position_txt': 'LF',
#   'primary_position': '7',
#   'jersey_number': '41',
#   'starter_sw': 'N',
#   'start_date': '2016-11-18T00:00:00',
#   'name_display_last_first': 'Andujar, Miguel',
#   'name_first': 'Miguel',
#   'name_use': 'Miguel',
#   'weight': '211',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2015-07-02T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Banuelos, Manny',
#   'name_display_first_last': 'Manny Banuelos',
#   'birth_date': '1991-03-13T00:00:00',
#   'height_inches': '10',
#   'team_id': '147',
#   'name_last': 'Banuelos',
#   'bats': 'R',
#   'player_id': '544365',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '68',
#   'starter_sw': 'N',
#   'start_date': '2022-05-26T00:00:00',
#   'name_display_last_first': 'Banuelos, Manny',
#   'name_first': 'Manuel',
#   'name_use': 'Manny',
#   'weight': '215',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Cabrera, Oswaldo',
#   'name_display_first_last': 'Oswaldo Cabrera',
#   'birth_date': '1999-03-01T00:00:00',
#   'height_inches': '10',
#   'team_id': '147',
#   'name_last': 'Cabrera',
#   'bats': 'S',
#   'player_id': '665828',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '95',
#   'starter_sw': 'N',
#   'start_date': '2021-11-19T00:00:00',
#   'name_display_last_first': 'Cabrera, Oswaldo',
#   'name_first': 'Oswaldo',
#   'name_use': 'Oswaldo',
#   'weight': '145',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': 'Texas Christian',
#   'end_date': '',
#   'pro_debut_date': '2011-06-04T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Carpenter, Matt',
#   'name_display_first_last': 'Matt Carpenter',
#   'birth_date': '1985-11-26T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'Carpenter',
#   'bats': 'L',
#   'player_id': '572761',
#   'position_txt': 'DH',
#   'primary_position': 'D',
#   'jersey_number': '24',
#   'starter_sw': 'N',
#   'start_date': '2022-05-26T00:00:00',
#   'name_display_last_first': 'Carpenter, Matt',
#   'name_first': 'Matthew',
#   'name_use': 'Matt',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2015-04-06T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Castro, Miguel',
#   'name_display_first_last': 'Miguel Castro',
#   'birth_date': '1994-12-24T00:00:00',
#   'height_inches': '7',
#   'team_id': '147',
#   'name_last': 'Castro',
#   'bats': 'R',
#   'player_id': '612434',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '30',
#   'starter_sw': 'N',
#   'start_date': '2022-04-03T00:00:00',
#   'name_display_last_first': 'Castro, Miguel',
#   'name_first': 'Miguel',
#   'name_use': 'Miguel',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2010-08-31T00:00:00',
#   'status_code': 'D15',
#   'name_full': 'Chapman, Aroldis',
#   'name_display_first_last': 'Aroldis Chapman',
#   'birth_date': '1988-02-28T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'Chapman',
#   'bats': 'L',
#   'player_id': '547973',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '54',
#   'starter_sw': 'N',
#   'start_date': '2016-12-15T00:00:00',
#   'name_display_last_first': 'Chapman, Aroldis',
#   'name_first': 'Albertin',
#   'name_use': 'Aroldis',
#   'weight': '218',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'UCLA',
#   'end_date': '',
#   'pro_debut_date': '2013-06-11T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Cole, Gerrit',
#   'name_display_first_last': 'Gerrit Cole',
#   'birth_date': '1990-09-08T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'Cole',
#   'bats': 'R',
#   'player_id': '543037',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '45',
#   'starter_sw': 'N',
#   'start_date': '2019-12-18T00:00:00',
#   'name_display_last_first': 'Cole, Gerrit',
#   'name_first': 'Gerrit',
#   'name_use': 'Gerrit',
#   'weight': '220',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-03-31T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Cortes, Nestor',
#   'name_display_first_last': 'Nestor Cortes',
#   'birth_date': '1994-12-10T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Cortes',
#   'bats': 'R',
#   'player_id': '641482',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '65',
#   'starter_sw': 'N',
#   'start_date': '2021-05-30T00:00:00',
#   'name_display_last_first': 'Cortes, Nestor',
#   'name_first': 'Nestor',
#   'name_use': 'Nestor',
#   'weight': '210',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': 'Auburn',
#   'end_date': '',
#   'pro_debut_date': '2010-04-30T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Donaldson, Josh',
#   'name_display_first_last': 'Josh Donaldson',
#   'birth_date': '1985-12-08T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Donaldson',
#   'bats': 'R',
#   'player_id': '518626',
#   'position_txt': '3B',
#   'primary_position': '5',
#   'jersey_number': '28',
#   'starter_sw': 'N',
#   'start_date': '2022-03-13T00:00:00',
#   'name_display_last_first': 'Donaldson, Josh',
#   'name_first': 'Joshua',
#   'name_use': 'Josh',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2020-08-28T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Florial, Estevan',
#   'name_display_first_last': 'Estevan Florial',
#   'birth_date': '1997-11-25T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Florial',
#   'bats': 'L',
#   'player_id': '664314',
#   'position_txt': 'CF',
#   'primary_position': '8',
#   'jersey_number': '90',
#   'starter_sw': 'N',
#   'start_date': '2019-11-20T00:00:00',
#   'name_display_last_first': 'Florial, Estevan',
#   'name_first': 'Estevan',
#   'name_use': 'Estevan',
#   'weight': '195',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2015-06-02T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Gallo, Joey',
#   'name_display_first_last': 'Joey Gallo',
#   'birth_date': '1993-11-19T00:00:00',
#   'height_inches': '5',
#   'team_id': '147',
#   'name_last': 'Gallo',
#   'bats': 'L',
#   'player_id': '608336',
#   'position_txt': 'LF',
#   'primary_position': '7',
#   'jersey_number': '13',
#   'starter_sw': 'N',
#   'start_date': '2021-07-29T00:00:00',
#   'name_display_last_first': 'Gallo, Joey',
#   'name_first': 'Joseph',
#   'name_use': 'Joey',
#   'weight': '250',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2020-08-30T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Garcia, Deivi',
#   'name_display_first_last': 'Deivi Garcia',
#   'birth_date': '1999-05-19T00:00:00',
#   'height_inches': '9',
#   'team_id': '147',
#   'name_last': 'Garcia',
#   'bats': 'R',
#   'player_id': '665620',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '83',
#   'starter_sw': 'N',
#   'start_date': '2019-11-20T00:00:00',
#   'name_display_last_first': 'Garcia, Deivi',
#   'name_first': 'Deivi',
#   'name_use': 'Deivi',
#   'weight': '163',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2021-08-03T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Gil, Luis',
#   'name_display_first_last': 'Luis Gil',
#   'birth_date': '1998-06-03T00:00:00',
#   'height_inches': '2',
#   'team_id': '147',
#   'name_last': 'Gil',
#   'bats': 'R',
#   'player_id': '661563',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '81',
#   'starter_sw': 'N',
#   'start_date': '2019-11-20T00:00:00',
#   'name_display_last_first': 'Gil, Luis',
#   'name_first': 'Luis',
#   'name_use': 'Luis',
#   'weight': '185',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Gomez, Yoendrys',
#   'name_display_first_last': 'Yoendrys Gomez',
#   'birth_date': '1999-10-15T00:00:00',
#   'height_inches': '3',
#   'team_id': '147',
#   'name_last': 'Gomez',
#   'bats': 'R',
#   'player_id': '672782',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '89',
#   'starter_sw': 'N',
#   'start_date': '2020-11-20T00:00:00',
#   'name_display_last_first': 'Gomez, Yoendrys',
#   'name_first': 'Yoendrys',
#   'name_use': 'Yoendrys',
#   'weight': '175',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2012-04-06T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Gonzalez, Marwin',
#   'name_display_first_last': 'Marwin Gonzalez',
#   'birth_date': '1989-03-14T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Gonzalez',
#   'bats': 'S',
#   'player_id': '503556',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '14',
#   'starter_sw': 'N',
#   'start_date': '2022-04-07T00:00:00',
#   'name_display_last_first': 'Gonzalez, Marwin',
#   'name_first': 'Marwin',
#   'name_use': 'Marwin',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2013-04-01T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Hicks, Aaron',
#   'name_display_first_last': 'Aaron Hicks',
#   'birth_date': '1989-10-02T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Hicks',
#   'bats': 'S',
#   'player_id': '543305',
#   'position_txt': 'CF',
#   'primary_position': '8',
#   'jersey_number': '31',
#   'starter_sw': 'N',
#   'start_date': '2015-11-11T00:00:00',
#   'name_display_last_first': 'Hicks, Aaron',
#   'name_first': 'Aaron',
#   'name_use': 'Aaron',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2017-04-10T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Higashioka, Kyle',
#   'name_display_first_last': 'Kyle Higashioka',
#   'birth_date': '1990-04-20T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Higashioka',
#   'bats': 'R',
#   'player_id': '543309',
#   'position_txt': 'C',
#   'primary_position': '2',
#   'jersey_number': '66',
#   'starter_sw': 'N',
#   'start_date': '2016-11-04T00:00:00',
#   'name_display_last_first': 'Higashioka, Kyle',
#   'name_first': 'Kyle',
#   'name_use': 'Kyle',
#   'weight': '202',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-04-06T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Holmes, Clay',
#   'name_display_first_last': 'Clay Holmes',
#   'birth_date': '1993-03-27T00:00:00',
#   'height_inches': '5',
#   'team_id': '147',
#   'name_last': 'Holmes',
#   'bats': 'R',
#   'player_id': '605280',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '35',
#   'starter_sw': 'N',
#   'start_date': '2021-07-26T00:00:00',
#   'name_display_last_first': 'Holmes, Clay',
#   'name_first': 'Clayton',
#   'name_use': 'Clay',
#   'weight': '245',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Fresno State',
#   'end_date': '',
#   'pro_debut_date': '2016-08-13T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Judge, Aaron',
#   'name_display_first_last': 'Aaron Judge',
#   'birth_date': '1992-04-26T00:00:00',
#   'height_inches': '7',
#   'team_id': '147',
#   'name_last': 'Judge',
#   'bats': 'R',
#   'player_id': '592450',
#   'position_txt': 'RF',
#   'primary_position': '9',
#   'jersey_number': '99',
#   'starter_sw': 'N',
#   'start_date': '2016-08-13T00:00:00',
#   'name_display_last_first': 'Judge, Aaron',
#   'name_first': 'Aaron',
#   'name_use': 'Aaron',
#   'weight': '282',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-04-10T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Kiner-Falefa, Isiah',
#   'name_display_first_last': 'Isiah Kiner-Falefa',
#   'birth_date': '1995-03-23T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Kiner-Falefa',
#   'bats': 'R',
#   'player_id': '643396',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '12',
#   'starter_sw': 'N',
#   'start_date': '2022-03-13T00:00:00',
#   'name_display_last_first': 'Kiner-Falefa, Isiah',
#   'name_first': 'Isiah',
#   'name_use': 'Isiah',
#   'weight': '190',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': 'Boston College',
#   'end_date': '',
#   'pro_debut_date': '2019-09-27T00:00:00',
#   'status_code': 'A',
#   'name_full': 'King, Michael',
#   'name_display_first_last': 'Michael King',
#   'birth_date': '1995-05-25T00:00:00',
#   'height_inches': '3',
#   'team_id': '147',
#   'name_last': 'King',
#   'bats': 'R',
#   'player_id': '650633',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '34',
#   'starter_sw': 'N',
#   'start_date': '2019-09-19T00:00:00',
#   'name_display_last_first': 'King, Michael',
#   'name_first': 'Michael',
#   'name_use': 'Michael',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Louisiana State',
#   'end_date': '',
#   'pro_debut_date': '2011-05-30T00:00:00',
#   'status_code': 'A',
#   'name_full': 'LeMahieu, DJ',
#   'name_display_first_last': 'DJ LeMahieu',
#   'birth_date': '1988-07-13T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'LeMahieu',
#   'bats': 'R',
#   'player_id': '518934',
#   'position_txt': '3B',
#   'primary_position': '5',
#   'jersey_number': '26',
#   'starter_sw': 'N',
#   'start_date': '2021-01-27T00:00:00',
#   'name_display_last_first': 'LeMahieu, DJ',
#   'name_first': 'David',
#   'name_use': 'DJ',
#   'weight': '220',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-06-15T00:00:00',
#   'status_code': 'D15',
#   'name_full': 'Loaisiga, Jonathan',
#   'name_display_first_last': 'Jonathan Loaisiga',
#   'birth_date': '1994-11-02T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Loaisiga',
#   'bats': 'R',
#   'player_id': '642528',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '43',
#   'starter_sw': 'N',
#   'start_date': '2017-11-20T00:00:00',
#   'name_display_last_first': 'Loaisiga, Jonathan',
#   'name_first': 'Jonathan',
#   'name_use': 'Jonathan',
#   'weight': '165',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': 'Ithaca, NY',
#   'end_date': '',
#   'pro_debut_date': '2017-09-29T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Locastro, Tim',
#   'name_display_first_last': 'Tim Locastro',
#   'birth_date': '1992-07-14T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Locastro',
#   'bats': 'R',
#   'player_id': '641796',
#   'position_txt': 'LF',
#   'primary_position': '7',
#   'jersey_number': '33',
#   'starter_sw': 'N',
#   'start_date': '2022-03-13T00:00:00',
#   'name_display_last_first': 'Locastro, Tim',
#   'name_first': 'Timothy',
#   'name_use': 'Tim',
#   'weight': '190',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Rice',
#   'end_date': '',
#   'pro_debut_date': '2012-04-07T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Luetge, Lucas',
#   'name_display_first_last': 'Lucas Luetge',
#   'birth_date': '1987-03-24T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'Luetge',
#   'bats': 'L',
#   'player_id': '476595',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '63',
#   'starter_sw': 'N',
#   'start_date': '2021-03-31T00:00:00',
#   'name_display_last_first': 'Luetge, Lucas',
#   'name_first': 'Lucas',
#   'name_use': 'Lucas',
#   'weight': '205',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Delaware',
#   'end_date': '',
#   'pro_debut_date': '2022-04-09T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Marinaccio, Ron',
#   'name_display_first_last': 'Ron Marinaccio',
#   'birth_date': '1995-07-01T00:00:00',
#   'height_inches': '2',
#   'team_id': '147',
#   'name_last': 'Marinaccio',
#   'bats': 'R',
#   'player_id': '676760',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '97',
#   'starter_sw': 'N',
#   'start_date': '2021-11-19T00:00:00',
#   'name_display_last_first': 'Marinaccio, Ron',
#   'name_first': 'Ronald',
#   'name_use': 'Ron',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Medina, Luis',
#   'name_display_first_last': 'Luis Medina',
#   'birth_date': '1999-05-03T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Medina',
#   'bats': 'R',
#   'player_id': '665622',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '80',
#   'starter_sw': 'N',
#   'start_date': '2019-11-20T00:00:00',
#   'name_display_last_first': 'Medina, Luis',
#   'name_first': 'Luis',
#   'name_use': 'Luis',
#   'weight': '175',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'South Carolina',
#   'end_date': '',
#   'pro_debut_date': '2017-04-12T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Montgomery, Jordan',
#   'name_display_first_last': 'Jordan Montgomery',
#   'birth_date': '1992-12-27T00:00:00',
#   'height_inches': '6',
#   'team_id': '147',
#   'name_last': 'Montgomery',
#   'bats': 'L',
#   'player_id': '656756',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '47',
#   'starter_sw': 'N',
#   'start_date': '2017-04-12T00:00:00',
#   'name_display_last_first': 'Montgomery, Jordan',
#   'name_first': 'Jordan',
#   'name_use': 'Jordan',
#   'weight': '228',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2016-09-04T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Peralta, Wandy',
#   'name_display_first_last': 'Wandy Peralta',
#   'birth_date': '1991-07-27T00:00:00',
#   'height_inches': '0',
#   'team_id': '147',
#   'name_last': 'Peralta',
#   'bats': 'L',
#   'player_id': '593974',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '58',
#   'starter_sw': 'N',
#   'start_date': '2021-04-27T00:00:00',
#   'name_display_last_first': 'Peralta, Wandy',
#   'name_first': 'Wandy',
#   'name_use': 'Wandy',
#   'weight': '217',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Peraza, Oswald',
#   'name_display_first_last': 'Oswald Peraza',
#   'birth_date': '2000-06-15T00:00:00',
#   'height_inches': '0',
#   'team_id': '147',
#   'name_last': 'Peraza',
#   'bats': 'R',
#   'player_id': '672724',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '91',
#   'starter_sw': 'N',
#   'start_date': '2020-11-20T00:00:00',
#   'name_display_last_first': 'Peraza, Oswald',
#   'name_first': 'Oswald',
#   'name_use': 'Oswald',
#   'weight': '165',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Pereira, Everson',
#   'name_display_first_last': 'Everson Pereira',
#   'birth_date': '2001-04-10T00:00:00',
#   'height_inches': '0',
#   'team_id': '147',
#   'name_last': 'Pereira',
#   'bats': 'R',
#   'player_id': '677592',
#   'position_txt': 'CF',
#   'primary_position': '8',
#   'jersey_number': '93',
#   'starter_sw': 'N',
#   'start_date': '2021-11-19T00:00:00',
#   'name_display_last_first': 'Pereira, Everson',
#   'name_first': 'Everson',
#   'name_use': 'Everson',
#   'weight': '191',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2011-06-09T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Rizzo, Anthony',
#   'name_display_first_last': 'Anthony Rizzo',
#   'birth_date': '1989-08-08T00:00:00',
#   'height_inches': '3',
#   'team_id': '147',
#   'name_last': 'Rizzo',
#   'bats': 'L',
#   'player_id': '519203',
#   'position_txt': '1B',
#   'primary_position': '3',
#   'jersey_number': '48',
#   'starter_sw': 'N',
#   'start_date': '2022-03-17T00:00:00',
#   'name_display_last_first': 'Rizzo, Anthony',
#   'name_first': 'Anthony',
#   'name_use': 'Anthony',
#   'weight': '240',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'South Carolina',
#   'end_date': '',
#   'pro_debut_date': '2020-09-04T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Schmidt, Clarke',
#   'name_display_first_last': 'Clarke Schmidt',
#   'birth_date': '1996-02-20T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Schmidt',
#   'bats': 'R',
#   'player_id': '657376',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '86',
#   'starter_sw': 'N',
#   'start_date': '2020-09-04T00:00:00',
#   'name_display_last_first': 'Schmidt, Clarke',
#   'name_first': 'Clarke',
#   'name_use': 'Clarke',
#   'weight': '209',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'The Citadel',
#   'end_date': '',
#   'pro_debut_date': '2022-04-13T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Sears, JP',
#   'name_display_first_last': 'JP Sears',
#   'birth_date': '1996-02-19T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Sears',
#   'bats': 'R',
#   'player_id': '676664',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '92',
#   'starter_sw': 'N',
#   'start_date': '2021-11-19T00:00:00',
#   'name_display_last_first': 'Sears, JP',
#   'name_first': 'John',
#   'name_use': 'JP',
#   'weight': '180',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2015-08-05T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Severino, Luis',
#   'name_display_first_last': 'Luis Severino',
#   'birth_date': '1994-02-20T00:00:00',
#   'height_inches': '2',
#   'team_id': '147',
#   'name_last': 'Severino',
#   'bats': 'R',
#   'player_id': '622663',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '40',
#   'starter_sw': 'N',
#   'start_date': '2015-08-05T00:00:00',
#   'name_display_last_first': 'Severino, Luis',
#   'name_first': 'Luis',
#   'name_use': 'Luis',
#   'weight': '218',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2010-06-08T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Stanton, Giancarlo',
#   'name_display_first_last': 'Giancarlo Stanton',
#   'birth_date': '1989-11-08T00:00:00',
#   'height_inches': '6',
#   'team_id': '147',
#   'name_last': 'Stanton',
#   'bats': 'R',
#   'player_id': '519317',
#   'position_txt': 'DH',
#   'primary_position': 'D',
#   'jersey_number': '27',
#   'starter_sw': 'N',
#   'start_date': '2017-12-11T00:00:00',
#   'name_display_last_first': 'Stanton, Giancarlo',
#   'name_first': 'Giancarlo',
#   'name_use': 'Giancarlo',
#   'weight': '245',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2016-06-08T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Taillon, Jameson',
#   'name_display_first_last': 'Jameson Taillon',
#   'birth_date': '1991-11-18T00:00:00',
#   'height_inches': '5',
#   'team_id': '147',
#   'name_last': 'Taillon',
#   'bats': 'R',
#   'player_id': '592791',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '50',
#   'starter_sw': 'N',
#   'start_date': '2021-01-24T00:00:00',
#   'name_display_last_first': 'Taillon, Jameson',
#   'name_first': 'Jameson',
#   'name_use': 'Jameson',
#   'weight': '230',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-04-22T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Torres, Gleyber',
#   'name_display_first_last': 'Gleyber Torres',
#   'birth_date': '1996-12-13T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Torres',
#   'bats': 'R',
#   'player_id': '650402',
#   'position_txt': '2B',
#   'primary_position': '4',
#   'jersey_number': '25',
#   'starter_sw': 'N',
#   'start_date': '2017-11-20T00:00:00',
#   'name_display_last_first': 'Torres, Gleyber',
#   'name_first': 'Gleyber',
#   'name_use': 'Gleyber',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Oral Roberts',
#   'end_date': '',
#   'pro_debut_date': '2018-06-15T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Trevino, Jose',
#   'name_display_first_last': 'Jose Trevino',
#   'birth_date': '1992-11-28T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Trevino',
#   'bats': 'R',
#   'player_id': '624431',
#   'position_txt': 'C',
#   'primary_position': '2',
#   'jersey_number': '39',
#   'starter_sw': 'N',
#   'start_date': '2022-04-02T00:00:00',
#   'name_display_last_first': 'Trevino, Jose',
#   'name_first': 'Jose',
#   'name_use': 'Jose',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'}]

# %%
mets_url = MLB_URL + f'/named.roster_40.bam?team_id=%27121%27'
mets_resp = requests.get(mets_url)

mets_dict = json.loads(mets_resp.text)['roster_40']['queryResults']['row']

# %%
# Url function
def current_40_man_roster(team_id):
    roster_url = MLB_URL + f'/named.roster_40.bam?team_id=%27{team_id}%27'
    
    resp = requests.get(roster_url)

    roster_dict = json.loads(resp.text)['roster_40']['queryResults']['row']
    return roster_dict

# %% [markdown]
# The only tricky thing is that running ```resp.json()``` on our response object returns a decoding error, which means the response we're getting back isn't valid json.
#
# If we look at the text with ```resp.text``` we can see the problem is the JSON is wrapped in parenthesis and has a semi-colon on the end. We could find a replace these characters like this:

# %%
# Note: Calling multiple methods like this in a row is called chaining.
clean_resp_text = (yankees_resp.text
                  .replace(')', '')
                  .replace(')', '')
                  .replace(';', ''))

# %%
# When chaining multiple methods together, write them over multple lines to make it clearer
# As opposed to:
clean_resp_text2 = (resp.text.replace('(','').replace(')', '').replace(';', ''))

# %%
yankees_dict = (json.loads(clean_resp_text)['roster_40']['queryResults']['row'])
yankees_dict
# Out:
# [{'college': '',
#   'end_date': '',
#   'pro_debut_date': '2020-08-08T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Abreu, Albert',
#   'name_display_first_last': 'Albert Abreu',
#   'birth_date': '1995-09-26T00:00:00',
#   'height_inches': '2',
#   'team_id': '147',
#   'name_last': 'Abreu',
#   'bats': 'R',
#   'player_id': '656061',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '',
#   'starter_sw': 'N',
#   'start_date': '2022-06-21T00:00:00',
#   'name_display_last_first': 'Abreu, Albert',
#   'name_first': 'Albert',
#   'name_use': 'Albert',
#   'weight': '190',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2017-06-28T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Andujar, Miguel',
#   'name_display_first_last': 'Miguel Andujar',
#   'birth_date': '1995-03-02T00:00:00',
#   'height_inches': '0',
#   'team_id': '147',
#   'name_last': 'Andujar',
#   'bats': 'R',
#   'player_id': '609280',
#   'position_txt': 'LF',
#   'primary_position': '7',
#   'jersey_number': '41',
#   'starter_sw': 'N',
#   'start_date': '2016-11-18T00:00:00',
#   'name_display_last_first': 'Andujar, Miguel',
#   'name_first': 'Miguel',
#   'name_use': 'Miguel',
#   'weight': '211',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2015-07-02T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Banuelos, Manny',
#   'name_display_first_last': 'Manny Banuelos',
#   'birth_date': '1991-03-13T00:00:00',
#   'height_inches': '10',
#   'team_id': '147',
#   'name_last': 'Banuelos',
#   'bats': 'R',
#   'player_id': '544365',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '68',
#   'starter_sw': 'N',
#   'start_date': '2022-05-26T00:00:00',
#   'name_display_last_first': 'Banuelos, Manny',
#   'name_first': 'Manuel',
#   'name_use': 'Manny',
#   'weight': '215',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Cabrera, Oswaldo',
#   'name_display_first_last': 'Oswaldo Cabrera',
#   'birth_date': '1999-03-01T00:00:00',
#   'height_inches': '10',
#   'team_id': '147',
#   'name_last': 'Cabrera',
#   'bats': 'S',
#   'player_id': '665828',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '95',
#   'starter_sw': 'N',
#   'start_date': '2021-11-19T00:00:00',
#   'name_display_last_first': 'Cabrera, Oswaldo',
#   'name_first': 'Oswaldo',
#   'name_use': 'Oswaldo',
#   'weight': '145',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': 'Texas Christian',
#   'end_date': '',
#   'pro_debut_date': '2011-06-04T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Carpenter, Matt',
#   'name_display_first_last': 'Matt Carpenter',
#   'birth_date': '1985-11-26T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'Carpenter',
#   'bats': 'L',
#   'player_id': '572761',
#   'position_txt': 'DH',
#   'primary_position': 'D',
#   'jersey_number': '24',
#   'starter_sw': 'N',
#   'start_date': '2022-05-26T00:00:00',
#   'name_display_last_first': 'Carpenter, Matt',
#   'name_first': 'Matthew',
#   'name_use': 'Matt',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2015-04-06T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Castro, Miguel',
#   'name_display_first_last': 'Miguel Castro',
#   'birth_date': '1994-12-24T00:00:00',
#   'height_inches': '7',
#   'team_id': '147',
#   'name_last': 'Castro',
#   'bats': 'R',
#   'player_id': '612434',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '30',
#   'starter_sw': 'N',
#   'start_date': '2022-04-03T00:00:00',
#   'name_display_last_first': 'Castro, Miguel',
#   'name_first': 'Miguel',
#   'name_use': 'Miguel',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2010-08-31T00:00:00',
#   'status_code': 'D15',
#   'name_full': 'Chapman, Aroldis',
#   'name_display_first_last': 'Aroldis Chapman',
#   'birth_date': '1988-02-28T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'Chapman',
#   'bats': 'L',
#   'player_id': '547973',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '54',
#   'starter_sw': 'N',
#   'start_date': '2016-12-15T00:00:00',
#   'name_display_last_first': 'Chapman, Aroldis',
#   'name_first': 'Albertin',
#   'name_use': 'Aroldis',
#   'weight': '218',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'UCLA',
#   'end_date': '',
#   'pro_debut_date': '2013-06-11T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Cole, Gerrit',
#   'name_display_first_last': 'Gerrit Cole',
#   'birth_date': '1990-09-08T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'Cole',
#   'bats': 'R',
#   'player_id': '543037',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '45',
#   'starter_sw': 'N',
#   'start_date': '2019-12-18T00:00:00',
#   'name_display_last_first': 'Cole, Gerrit',
#   'name_first': 'Gerrit',
#   'name_use': 'Gerrit',
#   'weight': '220',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-03-31T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Cortes, Nestor',
#   'name_display_first_last': 'Nestor Cortes',
#   'birth_date': '1994-12-10T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Cortes',
#   'bats': 'R',
#   'player_id': '641482',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '65',
#   'starter_sw': 'N',
#   'start_date': '2021-05-30T00:00:00',
#   'name_display_last_first': 'Cortes, Nestor',
#   'name_first': 'Nestor',
#   'name_use': 'Nestor',
#   'weight': '210',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': 'Auburn',
#   'end_date': '',
#   'pro_debut_date': '2010-04-30T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Donaldson, Josh',
#   'name_display_first_last': 'Josh Donaldson',
#   'birth_date': '1985-12-08T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Donaldson',
#   'bats': 'R',
#   'player_id': '518626',
#   'position_txt': '3B',
#   'primary_position': '5',
#   'jersey_number': '28',
#   'starter_sw': 'N',
#   'start_date': '2022-03-13T00:00:00',
#   'name_display_last_first': 'Donaldson, Josh',
#   'name_first': 'Joshua',
#   'name_use': 'Josh',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2020-08-28T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Florial, Estevan',
#   'name_display_first_last': 'Estevan Florial',
#   'birth_date': '1997-11-25T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Florial',
#   'bats': 'L',
#   'player_id': '664314',
#   'position_txt': 'CF',
#   'primary_position': '8',
#   'jersey_number': '90',
#   'starter_sw': 'N',
#   'start_date': '2019-11-20T00:00:00',
#   'name_display_last_first': 'Florial, Estevan',
#   'name_first': 'Estevan',
#   'name_use': 'Estevan',
#   'weight': '195',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2015-06-02T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Gallo, Joey',
#   'name_display_first_last': 'Joey Gallo',
#   'birth_date': '1993-11-19T00:00:00',
#   'height_inches': '5',
#   'team_id': '147',
#   'name_last': 'Gallo',
#   'bats': 'L',
#   'player_id': '608336',
#   'position_txt': 'LF',
#   'primary_position': '7',
#   'jersey_number': '13',
#   'starter_sw': 'N',
#   'start_date': '2021-07-29T00:00:00',
#   'name_display_last_first': 'Gallo, Joey',
#   'name_first': 'Joseph',
#   'name_use': 'Joey',
#   'weight': '250',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2020-08-30T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Garcia, Deivi',
#   'name_display_first_last': 'Deivi Garcia',
#   'birth_date': '1999-05-19T00:00:00',
#   'height_inches': '9',
#   'team_id': '147',
#   'name_last': 'Garcia',
#   'bats': 'R',
#   'player_id': '665620',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '83',
#   'starter_sw': 'N',
#   'start_date': '2019-11-20T00:00:00',
#   'name_display_last_first': 'Garcia, Deivi',
#   'name_first': 'Deivi',
#   'name_use': 'Deivi',
#   'weight': '163',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2021-08-03T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Gil, Luis',
#   'name_display_first_last': 'Luis Gil',
#   'birth_date': '1998-06-03T00:00:00',
#   'height_inches': '2',
#   'team_id': '147',
#   'name_last': 'Gil',
#   'bats': 'R',
#   'player_id': '661563',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '81',
#   'starter_sw': 'N',
#   'start_date': '2019-11-20T00:00:00',
#   'name_display_last_first': 'Gil, Luis',
#   'name_first': 'Luis',
#   'name_use': 'Luis',
#   'weight': '185',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Gomez, Yoendrys',
#   'name_display_first_last': 'Yoendrys Gomez',
#   'birth_date': '1999-10-15T00:00:00',
#   'height_inches': '3',
#   'team_id': '147',
#   'name_last': 'Gomez',
#   'bats': 'R',
#   'player_id': '672782',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '89',
#   'starter_sw': 'N',
#   'start_date': '2020-11-20T00:00:00',
#   'name_display_last_first': 'Gomez, Yoendrys',
#   'name_first': 'Yoendrys',
#   'name_use': 'Yoendrys',
#   'weight': '175',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2012-04-06T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Gonzalez, Marwin',
#   'name_display_first_last': 'Marwin Gonzalez',
#   'birth_date': '1989-03-14T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Gonzalez',
#   'bats': 'S',
#   'player_id': '503556',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '14',
#   'starter_sw': 'N',
#   'start_date': '2022-04-07T00:00:00',
#   'name_display_last_first': 'Gonzalez, Marwin',
#   'name_first': 'Marwin',
#   'name_use': 'Marwin',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2013-04-01T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Hicks, Aaron',
#   'name_display_first_last': 'Aaron Hicks',
#   'birth_date': '1989-10-02T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Hicks',
#   'bats': 'S',
#   'player_id': '543305',
#   'position_txt': 'CF',
#   'primary_position': '8',
#   'jersey_number': '31',
#   'starter_sw': 'N',
#   'start_date': '2015-11-11T00:00:00',
#   'name_display_last_first': 'Hicks, Aaron',
#   'name_first': 'Aaron',
#   'name_use': 'Aaron',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2017-04-10T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Higashioka, Kyle',
#   'name_display_first_last': 'Kyle Higashioka',
#   'birth_date': '1990-04-20T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Higashioka',
#   'bats': 'R',
#   'player_id': '543309',
#   'position_txt': 'C',
#   'primary_position': '2',
#   'jersey_number': '66',
#   'starter_sw': 'N',
#   'start_date': '2016-11-04T00:00:00',
#   'name_display_last_first': 'Higashioka, Kyle',
#   'name_first': 'Kyle',
#   'name_use': 'Kyle',
#   'weight': '202',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-04-06T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Holmes, Clay',
#   'name_display_first_last': 'Clay Holmes',
#   'birth_date': '1993-03-27T00:00:00',
#   'height_inches': '5',
#   'team_id': '147',
#   'name_last': 'Holmes',
#   'bats': 'R',
#   'player_id': '605280',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '35',
#   'starter_sw': 'N',
#   'start_date': '2021-07-26T00:00:00',
#   'name_display_last_first': 'Holmes, Clay',
#   'name_first': 'Clayton',
#   'name_use': 'Clay',
#   'weight': '245',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Fresno State',
#   'end_date': '',
#   'pro_debut_date': '2016-08-13T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Judge, Aaron',
#   'name_display_first_last': 'Aaron Judge',
#   'birth_date': '1992-04-26T00:00:00',
#   'height_inches': '7',
#   'team_id': '147',
#   'name_last': 'Judge',
#   'bats': 'R',
#   'player_id': '592450',
#   'position_txt': 'RF',
#   'primary_position': '9',
#   'jersey_number': '99',
#   'starter_sw': 'N',
#   'start_date': '2016-08-13T00:00:00',
#   'name_display_last_first': 'Judge, Aaron',
#   'name_first': 'Aaron',
#   'name_use': 'Aaron',
#   'weight': '282',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-04-10T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Kiner-Falefa, Isiah',
#   'name_display_first_last': 'Isiah Kiner-Falefa',
#   'birth_date': '1995-03-23T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Kiner-Falefa',
#   'bats': 'R',
#   'player_id': '643396',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '12',
#   'starter_sw': 'N',
#   'start_date': '2022-03-13T00:00:00',
#   'name_display_last_first': 'Kiner-Falefa, Isiah',
#   'name_first': 'Isiah',
#   'name_use': 'Isiah',
#   'weight': '190',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': 'Boston College',
#   'end_date': '',
#   'pro_debut_date': '2019-09-27T00:00:00',
#   'status_code': 'A',
#   'name_full': 'King, Michael',
#   'name_display_first_last': 'Michael King',
#   'birth_date': '1995-05-25T00:00:00',
#   'height_inches': '3',
#   'team_id': '147',
#   'name_last': 'King',
#   'bats': 'R',
#   'player_id': '650633',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '34',
#   'starter_sw': 'N',
#   'start_date': '2019-09-19T00:00:00',
#   'name_display_last_first': 'King, Michael',
#   'name_first': 'Michael',
#   'name_use': 'Michael',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Louisiana State',
#   'end_date': '',
#   'pro_debut_date': '2011-05-30T00:00:00',
#   'status_code': 'A',
#   'name_full': 'LeMahieu, DJ',
#   'name_display_first_last': 'DJ LeMahieu',
#   'birth_date': '1988-07-13T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'LeMahieu',
#   'bats': 'R',
#   'player_id': '518934',
#   'position_txt': '3B',
#   'primary_position': '5',
#   'jersey_number': '26',
#   'starter_sw': 'N',
#   'start_date': '2021-01-27T00:00:00',
#   'name_display_last_first': 'LeMahieu, DJ',
#   'name_first': 'David',
#   'name_use': 'DJ',
#   'weight': '220',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-06-15T00:00:00',
#   'status_code': 'D15',
#   'name_full': 'Loaisiga, Jonathan',
#   'name_display_first_last': 'Jonathan Loaisiga',
#   'birth_date': '1994-11-02T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Loaisiga',
#   'bats': 'R',
#   'player_id': '642528',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '43',
#   'starter_sw': 'N',
#   'start_date': '2017-11-20T00:00:00',
#   'name_display_last_first': 'Loaisiga, Jonathan',
#   'name_first': 'Jonathan',
#   'name_use': 'Jonathan',
#   'weight': '165',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': 'Ithaca, NY',
#   'end_date': '',
#   'pro_debut_date': '2017-09-29T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Locastro, Tim',
#   'name_display_first_last': 'Tim Locastro',
#   'birth_date': '1992-07-14T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Locastro',
#   'bats': 'R',
#   'player_id': '641796',
#   'position_txt': 'LF',
#   'primary_position': '7',
#   'jersey_number': '33',
#   'starter_sw': 'N',
#   'start_date': '2022-03-13T00:00:00',
#   'name_display_last_first': 'Locastro, Tim',
#   'name_first': 'Timothy',
#   'name_use': 'Tim',
#   'weight': '190',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Rice',
#   'end_date': '',
#   'pro_debut_date': '2012-04-07T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Luetge, Lucas',
#   'name_display_first_last': 'Lucas Luetge',
#   'birth_date': '1987-03-24T00:00:00',
#   'height_inches': '4',
#   'team_id': '147',
#   'name_last': 'Luetge',
#   'bats': 'L',
#   'player_id': '476595',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '63',
#   'starter_sw': 'N',
#   'start_date': '2021-03-31T00:00:00',
#   'name_display_last_first': 'Luetge, Lucas',
#   'name_first': 'Lucas',
#   'name_use': 'Lucas',
#   'weight': '205',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Delaware',
#   'end_date': '',
#   'pro_debut_date': '2022-04-09T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Marinaccio, Ron',
#   'name_display_first_last': 'Ron Marinaccio',
#   'birth_date': '1995-07-01T00:00:00',
#   'height_inches': '2',
#   'team_id': '147',
#   'name_last': 'Marinaccio',
#   'bats': 'R',
#   'player_id': '676760',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '97',
#   'starter_sw': 'N',
#   'start_date': '2021-11-19T00:00:00',
#   'name_display_last_first': 'Marinaccio, Ron',
#   'name_first': 'Ronald',
#   'name_use': 'Ron',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Medina, Luis',
#   'name_display_first_last': 'Luis Medina',
#   'birth_date': '1999-05-03T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Medina',
#   'bats': 'R',
#   'player_id': '665622',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '80',
#   'starter_sw': 'N',
#   'start_date': '2019-11-20T00:00:00',
#   'name_display_last_first': 'Medina, Luis',
#   'name_first': 'Luis',
#   'name_use': 'Luis',
#   'weight': '175',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'South Carolina',
#   'end_date': '',
#   'pro_debut_date': '2017-04-12T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Montgomery, Jordan',
#   'name_display_first_last': 'Jordan Montgomery',
#   'birth_date': '1992-12-27T00:00:00',
#   'height_inches': '6',
#   'team_id': '147',
#   'name_last': 'Montgomery',
#   'bats': 'L',
#   'player_id': '656756',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '47',
#   'starter_sw': 'N',
#   'start_date': '2017-04-12T00:00:00',
#   'name_display_last_first': 'Montgomery, Jordan',
#   'name_first': 'Jordan',
#   'name_use': 'Jordan',
#   'weight': '228',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2016-09-04T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Peralta, Wandy',
#   'name_display_first_last': 'Wandy Peralta',
#   'birth_date': '1991-07-27T00:00:00',
#   'height_inches': '0',
#   'team_id': '147',
#   'name_last': 'Peralta',
#   'bats': 'L',
#   'player_id': '593974',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '58',
#   'starter_sw': 'N',
#   'start_date': '2021-04-27T00:00:00',
#   'name_display_last_first': 'Peralta, Wandy',
#   'name_first': 'Wandy',
#   'name_use': 'Wandy',
#   'weight': '217',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Peraza, Oswald',
#   'name_display_first_last': 'Oswald Peraza',
#   'birth_date': '2000-06-15T00:00:00',
#   'height_inches': '0',
#   'team_id': '147',
#   'name_last': 'Peraza',
#   'bats': 'R',
#   'player_id': '672724',
#   'position_txt': 'SS',
#   'primary_position': '6',
#   'jersey_number': '91',
#   'starter_sw': 'N',
#   'start_date': '2020-11-20T00:00:00',
#   'name_display_last_first': 'Peraza, Oswald',
#   'name_first': 'Oswald',
#   'name_use': 'Oswald',
#   'weight': '165',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '',
#   'status_code': 'RM',
#   'name_full': 'Pereira, Everson',
#   'name_display_first_last': 'Everson Pereira',
#   'birth_date': '2001-04-10T00:00:00',
#   'height_inches': '0',
#   'team_id': '147',
#   'name_last': 'Pereira',
#   'bats': 'R',
#   'player_id': '677592',
#   'position_txt': 'CF',
#   'primary_position': '8',
#   'jersey_number': '93',
#   'starter_sw': 'N',
#   'start_date': '2021-11-19T00:00:00',
#   'name_display_last_first': 'Pereira, Everson',
#   'name_first': 'Everson',
#   'name_use': 'Everson',
#   'weight': '191',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2011-06-09T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Rizzo, Anthony',
#   'name_display_first_last': 'Anthony Rizzo',
#   'birth_date': '1989-08-08T00:00:00',
#   'height_inches': '3',
#   'team_id': '147',
#   'name_last': 'Rizzo',
#   'bats': 'L',
#   'player_id': '519203',
#   'position_txt': '1B',
#   'primary_position': '3',
#   'jersey_number': '48',
#   'starter_sw': 'N',
#   'start_date': '2022-03-17T00:00:00',
#   'name_display_last_first': 'Rizzo, Anthony',
#   'name_first': 'Anthony',
#   'name_use': 'Anthony',
#   'weight': '240',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'South Carolina',
#   'end_date': '',
#   'pro_debut_date': '2020-09-04T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Schmidt, Clarke',
#   'name_display_first_last': 'Clarke Schmidt',
#   'birth_date': '1996-02-20T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Schmidt',
#   'bats': 'R',
#   'player_id': '657376',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '86',
#   'starter_sw': 'N',
#   'start_date': '2020-09-04T00:00:00',
#   'name_display_last_first': 'Schmidt, Clarke',
#   'name_first': 'Clarke',
#   'name_use': 'Clarke',
#   'weight': '209',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'The Citadel',
#   'end_date': '',
#   'pro_debut_date': '2022-04-13T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Sears, JP',
#   'name_display_first_last': 'JP Sears',
#   'birth_date': '1996-02-19T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Sears',
#   'bats': 'R',
#   'player_id': '676664',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '92',
#   'starter_sw': 'N',
#   'start_date': '2021-11-19T00:00:00',
#   'name_display_last_first': 'Sears, JP',
#   'name_first': 'John',
#   'name_use': 'JP',
#   'weight': '180',
#   'throws': 'L',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2015-08-05T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Severino, Luis',
#   'name_display_first_last': 'Luis Severino',
#   'birth_date': '1994-02-20T00:00:00',
#   'height_inches': '2',
#   'team_id': '147',
#   'name_last': 'Severino',
#   'bats': 'R',
#   'player_id': '622663',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '40',
#   'starter_sw': 'N',
#   'start_date': '2015-08-05T00:00:00',
#   'name_display_last_first': 'Severino, Luis',
#   'name_first': 'Luis',
#   'name_use': 'Luis',
#   'weight': '218',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2010-06-08T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Stanton, Giancarlo',
#   'name_display_first_last': 'Giancarlo Stanton',
#   'birth_date': '1989-11-08T00:00:00',
#   'height_inches': '6',
#   'team_id': '147',
#   'name_last': 'Stanton',
#   'bats': 'R',
#   'player_id': '519317',
#   'position_txt': 'DH',
#   'primary_position': 'D',
#   'jersey_number': '27',
#   'starter_sw': 'N',
#   'start_date': '2017-12-11T00:00:00',
#   'name_display_last_first': 'Stanton, Giancarlo',
#   'name_first': 'Giancarlo',
#   'name_use': 'Giancarlo',
#   'weight': '245',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2016-06-08T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Taillon, Jameson',
#   'name_display_first_last': 'Jameson Taillon',
#   'birth_date': '1991-11-18T00:00:00',
#   'height_inches': '5',
#   'team_id': '147',
#   'name_last': 'Taillon',
#   'bats': 'R',
#   'player_id': '592791',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '50',
#   'starter_sw': 'N',
#   'start_date': '2021-01-24T00:00:00',
#   'name_display_last_first': 'Taillon, Jameson',
#   'name_first': 'Jameson',
#   'name_use': 'Jameson',
#   'weight': '230',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2018-04-22T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Torres, Gleyber',
#   'name_display_first_last': 'Gleyber Torres',
#   'birth_date': '1996-12-13T00:00:00',
#   'height_inches': '1',
#   'team_id': '147',
#   'name_last': 'Torres',
#   'bats': 'R',
#   'player_id': '650402',
#   'position_txt': '2B',
#   'primary_position': '4',
#   'jersey_number': '25',
#   'starter_sw': 'N',
#   'start_date': '2017-11-20T00:00:00',
#   'name_display_last_first': 'Torres, Gleyber',
#   'name_first': 'Gleyber',
#   'name_use': 'Gleyber',
#   'weight': '205',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': 'Oral Roberts',
#   'end_date': '',
#   'pro_debut_date': '2018-06-15T00:00:00',
#   'status_code': 'A',
#   'name_full': 'Trevino, Jose',
#   'name_display_first_last': 'Jose Trevino',
#   'birth_date': '1992-11-28T00:00:00',
#   'height_inches': '11',
#   'team_id': '147',
#   'name_last': 'Trevino',
#   'bats': 'R',
#   'player_id': '624431',
#   'position_txt': 'C',
#   'primary_position': '2',
#   'jersey_number': '39',
#   'starter_sw': 'N',
#   'start_date': '2022-04-02T00:00:00',
#   'name_display_last_first': 'Trevino, Jose',
#   'name_first': 'Jose',
#   'name_use': 'Jose',
#   'weight': '210',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '5'}]

# %%
yankees_dict[2]
# Out:
# {'college': '',
#  'end_date': '',
#  'pro_debut_date': '2015-07-02T00:00:00',
#  'status_code': 'A',
#  'name_full': 'Banuelos, Manny',
#  'name_display_first_last': 'Manny Banuelos',
#  'birth_date': '1991-03-13T00:00:00',
#  'height_inches': '10',
#  'team_id': '147',
#  'name_last': 'Banuelos',
#  'bats': 'R',
#  'player_id': '544365',
#  'position_txt': 'P',
#  'primary_position': '1',
#  'jersey_number': '68',
#  'starter_sw': 'N',
#  'start_date': '2022-05-26T00:00:00',
#  'name_display_last_first': 'Banuelos, Manny',
#  'name_first': 'Manuel',
#  'name_use': 'Manny',
#  'weight': '215',
#  'throws': 'L',
#  'team_name': 'New York Yankees',
#  'team_code': 'nya',
#  'team_abbrev': 'NYY',
#  'height_feet': '5'}

# %%
yankees_roster_df = pd.DataFrame(yankees_dict)
yankees_roster_df.loc[(yankees_roster_df['position_txt'] == 'P') & (yankees_roster_df['status_code'] != 'RM')]
# Out:
#            college end_date       pro_debut_date status_code  \
# 2                            2015-07-02T00:00:00           A
# 5                            2015-04-06T00:00:00           A
# 6                            2010-08-31T00:00:00         D15
# 7             UCLA           2013-06-11T00:00:00           A
# 8                            2018-03-31T00:00:00           A
# 18                           2018-04-06T00:00:00           A
# 21  Boston College           2019-09-27T00:00:00           A
# 23                           2018-06-15T00:00:00         D15
# 25            Rice           2012-04-07T00:00:00           A
# 26        Delaware           2022-04-09T00:00:00           A
# 28  South Carolina           2017-04-12T00:00:00           A
# 29                           2016-09-04T00:00:00           A
# 33  South Carolina           2020-09-04T00:00:00           A
# 35                           2015-08-05T00:00:00           A
# 37                           2016-06-08T00:00:00           A
#
#              name_full name_display_first_last           birth_date  \
# 2      Banuelos, Manny          Manny Banuelos  1991-03-13T00:00:00
# 5       Castro, Miguel           Miguel Castro  1994-12-24T00:00:00
# 6     Chapman, Aroldis         Aroldis Chapman  1988-02-28T00:00:00
# 7         Cole, Gerrit             Gerrit Cole  1990-09-08T00:00:00
# 8       Cortes, Nestor           Nestor Cortes  1994-12-10T00:00:00
# 18        Holmes, Clay             Clay Holmes  1993-03-27T00:00:00
# 21       King, Michael            Michael King  1995-05-25T00:00:00
# 23  Loaisiga, Jonathan       Jonathan Loaisiga  1994-11-02T00:00:00
# 25       Luetge, Lucas            Lucas Luetge  1987-03-24T00:00:00
# 26     Marinaccio, Ron          Ron Marinaccio  1995-07-01T00:00:00
# 28  Montgomery, Jordan       Jordan Montgomery  1992-12-27T00:00:00
# 29      Peralta, Wandy           Wandy Peralta  1991-07-27T00:00:00
# 33     Schmidt, Clarke          Clarke Schmidt  1996-02-20T00:00:00
# 35      Severino, Luis           Luis Severino  1994-02-20T00:00:00
# 37    Taillon, Jameson         Jameson Taillon  1991-11-18T00:00:00
#
#    height_inches team_id   name_last  ...           start_date  \
# 2             10     147    Banuelos  ...  2022-05-26T00:00:00
# 5              7     147      Castro  ...  2022-04-03T00:00:00
# 6              4     147     Chapman  ...  2016-12-15T00:00:00
# 7              4     147        Cole  ...  2019-12-18T00:00:00
# 8             11     147      Cortes  ...  2021-05-30T00:00:00
# 18             5     147      Holmes  ...  2021-07-26T00:00:00
# 21             3     147        King  ...  2019-09-19T00:00:00
# 23            11     147    Loaisiga  ...  2017-11-20T00:00:00
# 25             4     147      Luetge  ...  2021-03-31T00:00:00
# 26             2     147  Marinaccio  ...  2021-11-19T00:00:00
# 28             6     147  Montgomery  ...  2017-04-12T00:00:00
# 29             0     147     Peralta  ...  2021-04-27T00:00:00
# 33             1     147     Schmidt  ...  2020-09-04T00:00:00
# 35             2     147    Severino  ...  2015-08-05T00:00:00
# 37             5     147     Taillon  ...  2021-01-24T00:00:00
#
#    name_display_last_first name_first  name_use weight throws  \
# 2          Banuelos, Manny     Manuel     Manny    215      L
# 5           Castro, Miguel     Miguel    Miguel    205      R
# 6         Chapman, Aroldis   Albertin   Aroldis    218      L
# 7             Cole, Gerrit     Gerrit    Gerrit    220      R
# 8           Cortes, Nestor     Nestor    Nestor    210      L
# 18            Holmes, Clay    Clayton      Clay    245      R
# 21           King, Michael    Michael   Michael    210      R
# 23      Loaisiga, Jonathan   Jonathan  Jonathan    165      R
# 25           Luetge, Lucas      Lucas     Lucas    205      L
# 26         Marinaccio, Ron     Ronald       Ron    205      R
# 28      Montgomery, Jordan     Jordan    Jordan    228      L
# 29          Peralta, Wandy      Wandy     Wandy    217      L
# 33         Schmidt, Clarke     Clarke    Clarke    209      R
# 35          Severino, Luis       Luis      Luis    218      R
# 37        Taillon, Jameson    Jameson   Jameson    230      R
#
#            team_name team_code team_abbrev height_feet
# 2   New York Yankees       nya         NYY           5
# 5   New York Yankees       nya         NYY           6
# 6   New York Yankees       nya         NYY           6
# 7   New York Yankees       nya         NYY           6
# 8   New York Yankees       nya         NYY           5
# 18  New York Yankees       nya         NYY           6
# 21  New York Yankees       nya         NYY           6
# 23  New York Yankees       nya         NYY           5
# 25  New York Yankees       nya         NYY           6
# 26  New York Yankees       nya         NYY           6
# 28  New York Yankees       nya         NYY           6
# 29  New York Yankees       nya         NYY           6
# 33  New York Yankees       nya         NYY           6
# 35  New York Yankees       nya         NYY           6
# 37  New York Yankees       nya         NYY           6
#
# [15 rows x 26 columns]

# %%
yankees_roster_df.loc[(yankees_roster_df['position_txt'] != 'P') & (yankees_roster_df['status_code'] != 'RM')]
# Out:
#             college end_date       pro_debut_date status_code  \
# 4   Texas Christian           2011-06-04T00:00:00           A
# 9            Auburn           2010-04-30T00:00:00           A
# 11                            2015-06-02T00:00:00           A
# 15                            2012-04-06T00:00:00           A
# 16                            2013-04-01T00:00:00           A
# 17                            2017-04-10T00:00:00           A
# 19     Fresno State           2016-08-13T00:00:00           A
# 20                            2018-04-10T00:00:00           A
# 22  Louisiana State           2011-05-30T00:00:00           A
# 32                            2011-06-09T00:00:00           A
# 36                            2010-06-08T00:00:00           A
# 38                            2018-04-22T00:00:00           A
# 39     Oral Roberts           2018-06-15T00:00:00           A
#
#               name_full name_display_first_last           birth_date  \
# 4       Carpenter, Matt          Matt Carpenter  1985-11-26T00:00:00
# 9       Donaldson, Josh          Josh Donaldson  1985-12-08T00:00:00
# 11          Gallo, Joey              Joey Gallo  1993-11-19T00:00:00
# 15     Gonzalez, Marwin         Marwin Gonzalez  1989-03-14T00:00:00
# 16         Hicks, Aaron             Aaron Hicks  1989-10-02T00:00:00
# 17     Higashioka, Kyle         Kyle Higashioka  1990-04-20T00:00:00
# 19         Judge, Aaron             Aaron Judge  1992-04-26T00:00:00
# 20  Kiner-Falefa, Isiah      Isiah Kiner-Falefa  1995-03-23T00:00:00
# 22         LeMahieu, DJ             DJ LeMahieu  1988-07-13T00:00:00
# 32       Rizzo, Anthony           Anthony Rizzo  1989-08-08T00:00:00
# 36   Stanton, Giancarlo       Giancarlo Stanton  1989-11-08T00:00:00
# 38      Torres, Gleyber          Gleyber Torres  1996-12-13T00:00:00
# 39        Trevino, Jose            Jose Trevino  1992-11-28T00:00:00
#
#    height_inches team_id     name_last  ...           start_date  \
# 4              4     147     Carpenter  ...  2022-05-26T00:00:00
# 9              1     147     Donaldson  ...  2022-03-13T00:00:00
# 11             5     147         Gallo  ...  2021-07-29T00:00:00
# 15             1     147      Gonzalez  ...  2022-04-07T00:00:00
# 16             1     147         Hicks  ...  2015-11-11T00:00:00
# 17             1     147    Higashioka  ...  2016-11-04T00:00:00
# 19             7     147         Judge  ...  2016-08-13T00:00:00
# 20            11     147  Kiner-Falefa  ...  2022-03-13T00:00:00
# 22             4     147      LeMahieu  ...  2021-01-27T00:00:00
# 32             3     147         Rizzo  ...  2022-03-17T00:00:00
# 36             6     147       Stanton  ...  2017-12-11T00:00:00
# 38             1     147        Torres  ...  2017-11-20T00:00:00
# 39            11     147       Trevino  ...  2022-04-02T00:00:00
#
#    name_display_last_first name_first   name_use weight throws  \
# 4          Carpenter, Matt    Matthew       Matt    210      R
# 9          Donaldson, Josh     Joshua       Josh    210      R
# 11             Gallo, Joey     Joseph       Joey    250      R
# 15        Gonzalez, Marwin     Marwin     Marwin    205      R
# 16            Hicks, Aaron      Aaron      Aaron    205      R
# 17        Higashioka, Kyle       Kyle       Kyle    202      R
# 19            Judge, Aaron      Aaron      Aaron    282      R
# 20     Kiner-Falefa, Isiah      Isiah      Isiah    190      R
# 22            LeMahieu, DJ      David         DJ    220      R
# 32          Rizzo, Anthony    Anthony    Anthony    240      L
# 36      Stanton, Giancarlo  Giancarlo  Giancarlo    245      R
# 38         Torres, Gleyber    Gleyber    Gleyber    205      R
# 39           Trevino, Jose       Jose       Jose    210      R
#
#            team_name team_code team_abbrev height_feet
# 4   New York Yankees       nya         NYY           6
# 9   New York Yankees       nya         NYY           6
# 11  New York Yankees       nya         NYY           6
# 15  New York Yankees       nya         NYY           6
# 16  New York Yankees       nya         NYY           6
# 17  New York Yankees       nya         NYY           6
# 19  New York Yankees       nya         NYY           6
# 20  New York Yankees       nya         NYY           5
# 22  New York Yankees       nya         NYY           6
# 32  New York Yankees       nya         NYY           6
# 36  New York Yankees       nya         NYY           6
# 38  New York Yankees       nya         NYY           6
# 39  New York Yankees       nya         NYY           5
#
# [13 rows x 26 columns]

# %%
mets_roster_df = pd.DataFrame(mets_dict)
mets_roster_df.loc[(mets_roster_df['position_txt'] == 'P') & (mets_roster_df['status_code'] != 'RM')]
# Out:
#                            college end_date       pro_debut_date status_code  \
# 1                            Akron           2014-08-30T00:00:00           A
# 4                                            2009-09-01T00:00:00           A
# 6                                            2016-06-06T00:00:00           A
# 9                     Heartland CC           2022-05-15T00:00:00         D15
# 10                         Alabama           2008-08-01T00:00:00           A
# 14                                           2018-09-09T00:00:00           A
# 15  Centenary College of Louisiana           2016-07-01T00:00:00          PL
# 21                                           2020-09-20T00:00:00           A
# 22                         Arizona           2021-06-23T00:00:00         D15
# 26                    Northeastern           2010-05-29T00:00:00           A
# 27                          Oregon           2020-07-28T00:00:00           A
# 30                                           2016-09-11T00:00:00           A
# 31                        Missouri           2008-04-29T00:00:00         D15
# 32           CC of Southern Nevada           2014-07-19T00:00:00           A
# 34                  Dallas Baptist           2018-06-23T00:00:00           A
# 37                                           2013-08-30T00:00:00           A
# 38                   Arizona State           2016-09-07T00:00:00           A
#
#            name_full name_display_first_last           birth_date  \
# 1     Bassitt, Chris           Chris Bassitt  1989-02-22T00:00:00
# 4   Carrasco, Carlos         Carlos Carrasco  1987-03-21T00:00:00
# 6        Diaz, Edwin              Edwin Diaz  1994-03-22T00:00:00
# 9   Holderman, Colin         Colin Holderman  1995-10-08T00:00:00
# 10     Hunter, Tommy            Tommy Hunter  1986-07-03T00:00:00
# 14       Lopez, Yoan              Yoan Lopez  1993-01-02T00:00:00
# 15        Lugo, Seth               Seth Lugo  1989-11-17T00:00:00
# 21    Medina, Adonis           Adonis Medina  1996-12-18T00:00:00
# 22     Megill, Tylor            Tylor Megill  1995-07-28T00:00:00
# 26    Ottavino, Adam           Adam Ottavino  1985-11-22T00:00:00
# 27   Peterson, David          David Peterson  1995-09-03T00:00:00
# 30  Rodriguez, Joely         Joely Rodriguez  1991-11-14T00:00:00
# 31     Scherzer, Max            Max Scherzer  1984-07-27T00:00:00
# 32    Shreve, Chasen           Chasen Shreve  1990-07-12T00:00:00
# 34       Smith, Drew              Drew Smith  1993-09-24T00:00:00
# 37   Walker, Taijuan          Taijuan Walker  1992-08-13T00:00:00
# 38  Williams, Trevor         Trevor Williams  1992-04-25T00:00:00
#
#    height_inches team_id  name_last  ...           start_date  \
# 1              5     121    Bassitt  ...  2022-03-12T00:00:00
# 4              4     121   Carrasco  ...  2021-01-07T00:00:00
# 6              3     121       Diaz  ...  2018-12-03T00:00:00
# 9              7     121  Holderman  ...  2022-05-15T00:00:00
# 10             3     121     Hunter  ...  2022-06-17T00:00:00
# 14             3     121      Lopez  ...  2022-03-29T00:00:00
# 15             4     121       Lugo  ...  2015-11-20T00:00:00
# 21             1     121     Medina  ...  2022-04-07T00:00:00
# 22             7     121     Megill  ...  2021-06-23T00:00:00
# 26             5     121   Ottavino  ...  2022-03-14T00:00:00
# 27             6     121   Peterson  ...  2020-07-28T00:00:00
# 30             1     121  Rodriguez  ...  2022-04-03T00:00:00
# 31             3     121   Scherzer  ...  2021-11-30T00:00:00
# 32             4     121     Shreve  ...  2022-04-06T00:00:00
# 34             2     121      Smith  ...  2018-06-22T00:00:00
# 37             4     121     Walker  ...  2021-02-20T00:00:00
# 38             3     121   Williams  ...  2021-07-30T00:00:00
#
#    name_display_last_first   name_first name_use weight throws      team_name  \
# 1           Bassitt, Chris  Christopher    Chris    217      R  New York Mets
# 4         Carrasco, Carlos       Carlos   Carlos    224      R  New York Mets
# 6              Diaz, Edwin        Edwin    Edwin    165      R  New York Mets
# 9         Holderman, Colin        Colin    Colin    240      R  New York Mets
# 10           Hunter, Tommy      Raymond    Tommy    250      R  New York Mets
# 14             Lopez, Yoan         Yoan     Yoan    208      R  New York Mets
# 15              Lugo, Seth        Jacob     Seth    225      R  New York Mets
# 21          Medina, Adonis       Adonis   Adonis    187      R  New York Mets
# 22           Megill, Tylor        Tylor    Tylor    230      R  New York Mets
# 26          Ottavino, Adam         Adam     Adam    246      R  New York Mets
# 27         Peterson, David        David    David    240      L  New York Mets
# 30        Rodriguez, Joely        Joely    Joely    200      L  New York Mets
# 31           Scherzer, Max      Maxwell      Max    208      R  New York Mets
# 32          Shreve, Chasen       Chasen   Chasen    180      L  New York Mets
# 34             Smith, Drew       Andrew     Drew    190      R  New York Mets
# 37         Walker, Taijuan      Taijuan  Taijuan    235      R  New York Mets
# 38        Williams, Trevor       Trevor   Trevor    235      R  New York Mets
#
#    team_code team_abbrev height_feet
# 1        nyn         NYM           6
# 4        nyn         NYM           6
# 6        nyn         NYM           6
# 9        nyn         NYM           6
# 10       nyn         NYM           6
# 14       nyn         NYM           6
# 15       nyn         NYM           6
# 21       nyn         NYM           6
# 22       nyn         NYM           6
# 26       nyn         NYM           6
# 27       nyn         NYM           6
# 30       nyn         NYM           6
# 31       nyn         NYM           6
# 32       nyn         NYM           6
# 34       nyn         NYM           6
# 37       nyn         NYM           6
# 38       nyn         NYM           6
#
# [17 rows x 26 columns]

# %%
mets_roster_df.loc[(mets_roster_df['position_txt'] == 'P')]
# Out:
#                            college end_date       pro_debut_date status_code  \
# 1                            Akron           2014-08-30T00:00:00           A
# 2                                                                         RM
# 4                                            2009-09-01T00:00:00           A
# 6                                            2016-06-06T00:00:00           A
# 9                     Heartland CC           2022-05-15T00:00:00         D15
# 10                         Alabama           2008-08-01T00:00:00           A
# 14                                           2018-09-09T00:00:00           A
# 15  Centenary College of Louisiana           2016-07-01T00:00:00          PL
# 21                                           2020-09-20T00:00:00           A
# 22                         Arizona           2021-06-23T00:00:00         D15
# 25                          Oregon           2019-06-19T00:00:00          RM
# 26                    Northeastern           2010-05-29T00:00:00           A
# 27                          Oregon           2020-07-28T00:00:00           A
# 29                          Oregon           2021-07-06T00:00:00          RM
# 30                                           2016-09-11T00:00:00           A
# 31                        Missouri           2008-04-29T00:00:00         D15
# 32           CC of Southern Nevada           2014-07-19T00:00:00           A
# 34                  Dallas Baptist           2018-06-23T00:00:00           A
# 35                   South Alabama           2019-06-25T00:00:00          RM
# 37                                           2013-08-30T00:00:00           A
# 38                   Arizona State           2016-09-07T00:00:00           A
#
#            name_full name_display_first_last           birth_date  \
# 1     Bassitt, Chris           Chris Bassitt  1989-02-22T00:00:00
# 2        Butto, Jose              Jose Butto  1998-03-19T00:00:00
# 4   Carrasco, Carlos         Carlos Carrasco  1987-03-21T00:00:00
# 6        Diaz, Edwin              Edwin Diaz  1994-03-22T00:00:00
# 9   Holderman, Colin         Colin Holderman  1995-10-08T00:00:00
# 10     Hunter, Tommy            Tommy Hunter  1986-07-03T00:00:00
# 14       Lopez, Yoan              Yoan Lopez  1993-01-02T00:00:00
# 15        Lugo, Seth               Seth Lugo  1989-11-17T00:00:00
# 21    Medina, Adonis           Adonis Medina  1996-12-18T00:00:00
# 22     Megill, Tylor            Tylor Megill  1995-07-28T00:00:00
# 25  Nogosek, Stephen         Stephen Nogosek  1995-01-11T00:00:00
# 26    Ottavino, Adam           Adam Ottavino  1985-11-22T00:00:00
# 27   Peterson, David          David Peterson  1995-09-03T00:00:00
# 29        Reed, Jake               Jake Reed  1992-09-29T00:00:00
# 30  Rodriguez, Joely         Joely Rodriguez  1991-11-14T00:00:00
# 31     Scherzer, Max            Max Scherzer  1984-07-27T00:00:00
# 32    Shreve, Chasen           Chasen Shreve  1990-07-12T00:00:00
# 34       Smith, Drew              Drew Smith  1993-09-24T00:00:00
# 35   St. John, Locke          Locke St. John  1993-01-31T00:00:00
# 37   Walker, Taijuan          Taijuan Walker  1992-08-13T00:00:00
# 38  Williams, Trevor         Trevor Williams  1992-04-25T00:00:00
#
#    height_inches team_id  name_last  ...           start_date  \
# 1              5     121    Bassitt  ...  2022-03-12T00:00:00
# 2              1     121      Butto  ...  2021-11-19T00:00:00
# 4              4     121   Carrasco  ...  2021-01-07T00:00:00
# 6              3     121       Diaz  ...  2018-12-03T00:00:00
# 9              7     121  Holderman  ...  2022-05-15T00:00:00
# 10             3     121     Hunter  ...  2022-06-17T00:00:00
# 14             3     121      Lopez  ...  2022-03-29T00:00:00
# 15             4     121       Lugo  ...  2015-11-20T00:00:00
# 21             1     121     Medina  ...  2022-04-07T00:00:00
# 22             7     121     Megill  ...  2021-06-23T00:00:00
# 25             2     121    Nogosek  ...  2022-05-08T00:00:00
# 26             5     121   Ottavino  ...  2022-03-14T00:00:00
# 27             6     121   Peterson  ...  2020-07-28T00:00:00
# 29             2     121       Reed  ...  2021-08-02T00:00:00
# 30             1     121  Rodriguez  ...  2022-04-03T00:00:00
# 31             3     121   Scherzer  ...  2021-11-30T00:00:00
# 32             4     121     Shreve  ...  2022-04-06T00:00:00
# 34             2     121      Smith  ...  2018-06-22T00:00:00
# 35             3     121   St. John  ...  2022-05-10T00:00:00
# 37             4     121     Walker  ...  2021-02-20T00:00:00
# 38             3     121   Williams  ...  2021-07-30T00:00:00
#
#    name_display_last_first   name_first name_use weight throws      team_name  \
# 1           Bassitt, Chris  Christopher    Chris    217      R  New York Mets
# 2              Butto, Jose         Jose     Jose    202      R  New York Mets
# 4         Carrasco, Carlos       Carlos   Carlos    224      R  New York Mets
# 6              Diaz, Edwin        Edwin    Edwin    165      R  New York Mets
# 9         Holderman, Colin        Colin    Colin    240      R  New York Mets
# 10           Hunter, Tommy      Raymond    Tommy    250      R  New York Mets
# 14             Lopez, Yoan         Yoan     Yoan    208      R  New York Mets
# 15              Lugo, Seth        Jacob     Seth    225      R  New York Mets
# 21          Medina, Adonis       Adonis   Adonis    187      R  New York Mets
# 22           Megill, Tylor        Tylor    Tylor    230      R  New York Mets
# 25        Nogosek, Stephen      Stephen  Stephen    205      R  New York Mets
# 26          Ottavino, Adam         Adam     Adam    246      R  New York Mets
# 27         Peterson, David        David    David    240      L  New York Mets
# 29              Reed, Jake        Jacob     Jake    195      R  New York Mets
# 30        Rodriguez, Joely        Joely    Joely    200      L  New York Mets
# 31           Scherzer, Max      Maxwell      Max    208      R  New York Mets
# 32          Shreve, Chasen       Chasen   Chasen    180      L  New York Mets
# 34             Smith, Drew       Andrew     Drew    190      R  New York Mets
# 35         St. John, Locke       Kenton    Locke    180      L  New York Mets
# 37         Walker, Taijuan      Taijuan  Taijuan    235      R  New York Mets
# 38        Williams, Trevor       Trevor   Trevor    235      R  New York Mets
#
#    team_code team_abbrev height_feet
# 1        nyn         NYM           6
# 2        nyn         NYM           6
# 4        nyn         NYM           6
# 6        nyn         NYM           6
# 9        nyn         NYM           6
# 10       nyn         NYM           6
# 14       nyn         NYM           6
# 15       nyn         NYM           6
# 21       nyn         NYM           6
# 22       nyn         NYM           6
# 25       nyn         NYM           6
# 26       nyn         NYM           6
# 27       nyn         NYM           6
# 29       nyn         NYM           6
# 30       nyn         NYM           6
# 31       nyn         NYM           6
# 32       nyn         NYM           6
# 34       nyn         NYM           6
# 35       nyn         NYM           6
# 37       nyn         NYM           6
# 38       nyn         NYM           6
#
# [21 rows x 26 columns]

# %%
mets_roster_df.loc[(mets_roster_df['position_txt'] != 'P') & (yankees_roster_df['status_code'] != 'RM')]
# Out:
#                 college end_date       pro_debut_date status_code  \
# 5   Cal State Fullerton           2017-08-05T00:00:00           A
# 7                                 2011-09-02T00:00:00           A
# 8                                 2018-05-11T00:00:00           A
# 11     SUNY Stony Brook           2015-08-21T00:00:00         D10
# 16                                2012-07-26T00:00:00           A
# 17                                                             RM
# 18              Stetson           2021-04-11T00:00:00           A
# 19             Arkansas           2014-09-01T00:00:00         D10
# 20     Long Beach State           2018-07-24T00:00:00           A
# 23                                2017-09-13T00:00:00           A
# 28                                2022-04-15T00:00:00           A
# 33                                2017-08-11T00:00:00           A
# 36                                                             RM
#
#             name_full name_display_first_last           birth_date  \
# 5         Davis, J.D.              J.D. Davis  1993-04-27T00:00:00
# 7    Escobar, Eduardo         Eduardo Escobar  1989-01-05T00:00:00
# 8     Guillorme, Luis          Luis Guillorme  1994-09-27T00:00:00
# 11  Jankowski, Travis        Travis Jankowski  1991-06-15T00:00:00
# 16    Marte, Starling          Starling Marte  1988-10-09T00:00:00
# 17    Mauricio, Ronny          Ronny Mauricio  2001-04-04T00:00:00
# 18   Mazeika, Patrick         Patrick Mazeika  1993-10-14T00:00:00
# 19      McCann, James            James McCann  1990-06-13T00:00:00
# 20       McNeil, Jeff             Jeff McNeil  1992-04-08T00:00:00
# 23        Nido, Tomas              Tomas Nido  1994-04-12T00:00:00
# 28      Plummer, Nick            Nick Plummer  1996-07-31T00:00:00
# 33     Smith, Dominic           Dominic Smith  1995-06-15T00:00:00
# 36      Vientos, Mark            Mark Vientos  1999-12-11T00:00:00
#
#    height_inches team_id  name_last  ...           start_date  \
# 5              3     121      Davis  ...  2019-01-06T00:00:00
# 7             10     121    Escobar  ...  2021-12-01T00:00:00
# 8             10     121  Guillorme  ...  2017-11-20T00:00:00
# 11             2     121  Jankowski  ...  2022-04-06T00:00:00
# 16             1     121      Marte  ...  2021-11-30T00:00:00
# 17             3     121   Mauricio  ...  2021-11-19T00:00:00
# 18             3     121    Mazeika  ...  2020-08-25T00:00:00
# 19             3     121     McCann  ...  2020-12-15T00:00:00
# 20             1     121     McNeil  ...  2018-07-24T00:00:00
# 23             0     121       Nido  ...  2016-11-18T00:00:00
# 28            10     121    Plummer  ...  2021-11-24T00:00:00
# 33             0     121      Smith  ...  2017-08-11T00:00:00
# 36             4     121    Vientos  ...  2021-11-19T00:00:00
#
#    name_display_last_first name_first  name_use weight throws      team_name  \
# 5              Davis, J.D.   Jonathan      J.D.    218      R  New York Mets
# 7         Escobar, Eduardo    Eduardo   Eduardo    193      R  New York Mets
# 8          Guillorme, Luis       Luis      Luis    190      R  New York Mets
# 11       Jankowski, Travis     Travis    Travis    190      R  New York Mets
# 16         Marte, Starling   Starling  Starling    195      R  New York Mets
# 17         Mauricio, Ronny      Ronny     Ronny    166      R  New York Mets
# 18        Mazeika, Patrick    Patrick   Patrick    210      R  New York Mets
# 19           McCann, James      James     James    220      R  New York Mets
# 20            McNeil, Jeff       Jeff      Jeff    195      R  New York Mets
# 23             Nido, Tomas      Tomas     Tomas    211      R  New York Mets
# 28           Plummer, Nick   Nicholas      Nick    200      L  New York Mets
# 33          Smith, Dominic    Dominic   Dominic    239      L  New York Mets
# 36           Vientos, Mark       Mark      Mark    185      R  New York Mets
#
#    team_code team_abbrev height_feet
# 5        nyn         NYM           6
# 7        nyn         NYM           5
# 8        nyn         NYM           5
# 11       nyn         NYM           6
# 16       nyn         NYM           6
# 17       nyn         NYM           6
# 18       nyn         NYM           6
# 19       nyn         NYM           6
# 20       nyn         NYM           6
# 23       nyn         NYM           6
# 28       nyn         NYM           5
# 33       nyn         NYM           6
# 36       nyn         NYM           6
#
# [13 rows x 26 columns]

# %% [markdown]
# To reverse making a DataFrame (maybe to write your own API that needs to return JSON or something) you can do:

# %%
yankees_roster_df.head(2).to_dict('records')
# Out:
# [{'college': '',
#   'end_date': '',
#   'pro_debut_date': '2020-08-08T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Abreu, Albert',
#   'name_display_first_last': 'Albert Abreu',
#   'birth_date': '1995-09-26T00:00:00',
#   'height_inches': '2',
#   'team_id': '147',
#   'name_last': 'Abreu',
#   'bats': 'R',
#   'player_id': '656061',
#   'position_txt': 'P',
#   'primary_position': '1',
#   'jersey_number': '',
#   'starter_sw': 'N',
#   'start_date': '2022-06-21T00:00:00',
#   'name_display_last_first': 'Abreu, Albert',
#   'name_first': 'Albert',
#   'name_use': 'Albert',
#   'weight': '190',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'},
#  {'college': '',
#   'end_date': '',
#   'pro_debut_date': '2017-06-28T00:00:00',
#   'status_code': 'RM',
#   'name_full': 'Andujar, Miguel',
#   'name_display_first_last': 'Miguel Andujar',
#   'birth_date': '1995-03-02T00:00:00',
#   'height_inches': '0',
#   'team_id': '147',
#   'name_last': 'Andujar',
#   'bats': 'R',
#   'player_id': '609280',
#   'position_txt': 'LF',
#   'primary_position': '7',
#   'jersey_number': '41',
#   'starter_sw': 'N',
#   'start_date': '2016-11-18T00:00:00',
#   'name_display_last_first': 'Andujar, Miguel',
#   'name_first': 'Miguel',
#   'name_use': 'Miguel',
#   'weight': '211',
#   'throws': 'R',
#   'team_name': 'New York Yankees',
#   'team_code': 'nya',
#   'team_abbrev': 'NYY',
#   'height_feet': '6'}]

# %%
def clean_json(resp):
    return json.loads(resp.text
                  .replace(')', '')
                  .replace(')', '')
                  .replace(';', ''))

# %% [markdown]
# # CAUTION:
# ### ```roster40```
# below only has an endpoint for the current year AND always returns the current roster so doing ```pd.concat``` with ```teams_by_year``` is  controversial. For example, if you change ```teams_2020``` parameter to '1900' about 5 cells down, the function ```roster40``` will only be able to return CURRENT players (2022) to teams that were physically around in the year '1900'. To get a better idea of stats from a specific year, the endpoint from the API must include the ```season``` parameter to avoid confusion

# %%
def roster40(team_id):
    roster_url = MLB_URL + f'/named.roster_40.bam?team_id=%27{team_id}%27'
    
    resp = requests.get(roster_url)

    team_json = clean_json(resp)
    return DataFrame(team_json['roster_40']['queryResults']['row'])

# %%
YANKEES_CURRENT_ROSTER = roster40(147)
YANKEES_CURRENT_ROSTER
# Out:
#             college end_date       pro_debut_date status_code  \
# 0                             2020-08-08T00:00:00          RM
# 1                             2017-06-28T00:00:00          RM
# 2                             2015-07-02T00:00:00           A
# 3                                                          RM
# 4   Texas Christian           2011-06-04T00:00:00           A
# 5                             2015-04-06T00:00:00           A
# 6                             2010-08-31T00:00:00         D15
# 7              UCLA           2013-06-11T00:00:00           A
# 8                             2018-03-31T00:00:00           A
# 9            Auburn           2010-04-30T00:00:00           A
# 10                            2020-08-28T00:00:00          RM
# 11                            2015-06-02T00:00:00           A
# 12                            2020-08-30T00:00:00          RM
# 13                            2021-08-03T00:00:00          RM
# 14                                                         RM
# 15                            2012-04-06T00:00:00           A
# 16                            2013-04-01T00:00:00           A
# 17                            2017-04-10T00:00:00           A
# 18                            2018-04-06T00:00:00           A
# 19     Fresno State           2016-08-13T00:00:00           A
# 20                            2018-04-10T00:00:00           A
# 21   Boston College           2019-09-27T00:00:00           A
# 22  Louisiana State           2011-05-30T00:00:00           A
# 23                            2018-06-15T00:00:00         D15
# 24       Ithaca, NY           2017-09-29T00:00:00          RM
# 25             Rice           2012-04-07T00:00:00           A
# 26         Delaware           2022-04-09T00:00:00           A
# 27                                                         RM
# 28   South Carolina           2017-04-12T00:00:00           A
# 29                            2016-09-04T00:00:00           A
# 30                                                         RM
# 31                                                         RM
# 32                            2011-06-09T00:00:00           A
# 33   South Carolina           2020-09-04T00:00:00           A
# 34      The Citadel           2022-04-13T00:00:00          RM
# 35                            2015-08-05T00:00:00           A
# 36                            2010-06-08T00:00:00           A
# 37                            2016-06-08T00:00:00           A
# 38                            2018-04-22T00:00:00           A
# 39     Oral Roberts           2018-06-15T00:00:00           A
#
#               name_full name_display_first_last           birth_date  \
# 0         Abreu, Albert            Albert Abreu  1995-09-26T00:00:00
# 1       Andujar, Miguel          Miguel Andujar  1995-03-02T00:00:00
# 2       Banuelos, Manny          Manny Banuelos  1991-03-13T00:00:00
# 3      Cabrera, Oswaldo         Oswaldo Cabrera  1999-03-01T00:00:00
# 4       Carpenter, Matt          Matt Carpenter  1985-11-26T00:00:00
# 5        Castro, Miguel           Miguel Castro  1994-12-24T00:00:00
# 6      Chapman, Aroldis         Aroldis Chapman  1988-02-28T00:00:00
# 7          Cole, Gerrit             Gerrit Cole  1990-09-08T00:00:00
# 8        Cortes, Nestor           Nestor Cortes  1994-12-10T00:00:00
# 9       Donaldson, Josh          Josh Donaldson  1985-12-08T00:00:00
# 10     Florial, Estevan         Estevan Florial  1997-11-25T00:00:00
# 11          Gallo, Joey              Joey Gallo  1993-11-19T00:00:00
# 12        Garcia, Deivi            Deivi Garcia  1999-05-19T00:00:00
# 13            Gil, Luis                Luis Gil  1998-06-03T00:00:00
# 14      Gomez, Yoendrys          Yoendrys Gomez  1999-10-15T00:00:00
# 15     Gonzalez, Marwin         Marwin Gonzalez  1989-03-14T00:00:00
# 16         Hicks, Aaron             Aaron Hicks  1989-10-02T00:00:00
# 17     Higashioka, Kyle         Kyle Higashioka  1990-04-20T00:00:00
# 18         Holmes, Clay             Clay Holmes  1993-03-27T00:00:00
# 19         Judge, Aaron             Aaron Judge  1992-04-26T00:00:00
# 20  Kiner-Falefa, Isiah      Isiah Kiner-Falefa  1995-03-23T00:00:00
# 21        King, Michael            Michael King  1995-05-25T00:00:00
# 22         LeMahieu, DJ             DJ LeMahieu  1988-07-13T00:00:00
# 23   Loaisiga, Jonathan       Jonathan Loaisiga  1994-11-02T00:00:00
# 24        Locastro, Tim            Tim Locastro  1992-07-14T00:00:00
# 25        Luetge, Lucas            Lucas Luetge  1987-03-24T00:00:00
# 26      Marinaccio, Ron          Ron Marinaccio  1995-07-01T00:00:00
# 27         Medina, Luis             Luis Medina  1999-05-03T00:00:00
# 28   Montgomery, Jordan       Jordan Montgomery  1992-12-27T00:00:00
# 29       Peralta, Wandy           Wandy Peralta  1991-07-27T00:00:00
# 30       Peraza, Oswald           Oswald Peraza  2000-06-15T00:00:00
# 31     Pereira, Everson         Everson Pereira  2001-04-10T00:00:00
# 32       Rizzo, Anthony           Anthony Rizzo  1989-08-08T00:00:00
# 33      Schmidt, Clarke          Clarke Schmidt  1996-02-20T00:00:00
# 34            Sears, JP                JP Sears  1996-02-19T00:00:00
# 35       Severino, Luis           Luis Severino  1994-02-20T00:00:00
# 36   Stanton, Giancarlo       Giancarlo Stanton  1989-11-08T00:00:00
# 37     Taillon, Jameson         Jameson Taillon  1991-11-18T00:00:00
# 38      Torres, Gleyber          Gleyber Torres  1996-12-13T00:00:00
# 39        Trevino, Jose            Jose Trevino  1992-11-28T00:00:00
#
#    height_inches team_id     name_last  ...           start_date  \
# 0              2     147         Abreu  ...  2022-06-21T00:00:00
# 1              0     147       Andujar  ...  2016-11-18T00:00:00
# 2             10     147      Banuelos  ...  2022-05-26T00:00:00
# 3             10     147       Cabrera  ...  2021-11-19T00:00:00
# 4              4     147     Carpenter  ...  2022-05-26T00:00:00
# 5              7     147        Castro  ...  2022-04-03T00:00:00
# 6              4     147       Chapman  ...  2016-12-15T00:00:00
# 7              4     147          Cole  ...  2019-12-18T00:00:00
# 8             11     147        Cortes  ...  2021-05-30T00:00:00
# 9              1     147     Donaldson  ...  2022-03-13T00:00:00
# 10             1     147       Florial  ...  2019-11-20T00:00:00
# 11             5     147         Gallo  ...  2021-07-29T00:00:00
# 12             9     147        Garcia  ...  2019-11-20T00:00:00
# 13             2     147           Gil  ...  2019-11-20T00:00:00
# 14             3     147         Gomez  ...  2020-11-20T00:00:00
# 15             1     147      Gonzalez  ...  2022-04-07T00:00:00
# 16             1     147         Hicks  ...  2015-11-11T00:00:00
# 17             1     147    Higashioka  ...  2016-11-04T00:00:00
# 18             5     147        Holmes  ...  2021-07-26T00:00:00
# 19             7     147         Judge  ...  2016-08-13T00:00:00
# 20            11     147  Kiner-Falefa  ...  2022-03-13T00:00:00
# 21             3     147          King  ...  2019-09-19T00:00:00
# 22             4     147      LeMahieu  ...  2021-01-27T00:00:00
# 23            11     147      Loaisiga  ...  2017-11-20T00:00:00
# 24             1     147      Locastro  ...  2022-03-13T00:00:00
# 25             4     147        Luetge  ...  2021-03-31T00:00:00
# 26             2     147    Marinaccio  ...  2021-11-19T00:00:00
# 27             1     147        Medina  ...  2019-11-20T00:00:00
# 28             6     147    Montgomery  ...  2017-04-12T00:00:00
# 29             0     147       Peralta  ...  2021-04-27T00:00:00
# 30             0     147        Peraza  ...  2020-11-20T00:00:00
# 31             0     147       Pereira  ...  2021-11-19T00:00:00
# 32             3     147         Rizzo  ...  2022-03-17T00:00:00
# 33             1     147       Schmidt  ...  2020-09-04T00:00:00
# 34            11     147         Sears  ...  2021-11-19T00:00:00
# 35             2     147      Severino  ...  2015-08-05T00:00:00
# 36             6     147       Stanton  ...  2017-12-11T00:00:00
# 37             5     147       Taillon  ...  2021-01-24T00:00:00
# 38             1     147        Torres  ...  2017-11-20T00:00:00
# 39            11     147       Trevino  ...  2022-04-02T00:00:00
#
#    name_display_last_first name_first   name_use weight throws  \
# 0            Abreu, Albert     Albert     Albert    190      R
# 1          Andujar, Miguel     Miguel     Miguel    211      R
# 2          Banuelos, Manny     Manuel      Manny    215      L
# 3         Cabrera, Oswaldo    Oswaldo    Oswaldo    145      R
# 4          Carpenter, Matt    Matthew       Matt    210      R
# 5           Castro, Miguel     Miguel     Miguel    205      R
# 6         Chapman, Aroldis   Albertin    Aroldis    218      L
# 7             Cole, Gerrit     Gerrit     Gerrit    220      R
# 8           Cortes, Nestor     Nestor     Nestor    210      L
# 9          Donaldson, Josh     Joshua       Josh    210      R
# 10        Florial, Estevan    Estevan    Estevan    195      R
# 11             Gallo, Joey     Joseph       Joey    250      R
# 12           Garcia, Deivi      Deivi      Deivi    163      R
# 13               Gil, Luis       Luis       Luis    185      R
# 14         Gomez, Yoendrys   Yoendrys   Yoendrys    175      R
# 15        Gonzalez, Marwin     Marwin     Marwin    205      R
# 16            Hicks, Aaron      Aaron      Aaron    205      R
# 17        Higashioka, Kyle       Kyle       Kyle    202      R
# 18            Holmes, Clay    Clayton       Clay    245      R
# 19            Judge, Aaron      Aaron      Aaron    282      R
# 20     Kiner-Falefa, Isiah      Isiah      Isiah    190      R
# 21           King, Michael    Michael    Michael    210      R
# 22            LeMahieu, DJ      David         DJ    220      R
# 23      Loaisiga, Jonathan   Jonathan   Jonathan    165      R
# 24           Locastro, Tim    Timothy        Tim    190      R
# 25           Luetge, Lucas      Lucas      Lucas    205      L
# 26         Marinaccio, Ron     Ronald        Ron    205      R
# 27            Medina, Luis       Luis       Luis    175      R
# 28      Montgomery, Jordan     Jordan     Jordan    228      L
# 29          Peralta, Wandy      Wandy      Wandy    217      L
# 30          Peraza, Oswald     Oswald     Oswald    165      R
# 31        Pereira, Everson    Everson    Everson    191      R
# 32          Rizzo, Anthony    Anthony    Anthony    240      L
# 33         Schmidt, Clarke     Clarke     Clarke    209      R
# 34               Sears, JP       John         JP    180      L
# 35          Severino, Luis       Luis       Luis    218      R
# 36      Stanton, Giancarlo  Giancarlo  Giancarlo    245      R
# 37        Taillon, Jameson    Jameson    Jameson    230      R
# 38         Torres, Gleyber    Gleyber    Gleyber    205      R
# 39           Trevino, Jose       Jose       Jose    210      R
#
#            team_name team_code team_abbrev height_feet
# 0   New York Yankees       nya         NYY           6
# 1   New York Yankees       nya         NYY           6
# 2   New York Yankees       nya         NYY           5
# 3   New York Yankees       nya         NYY           5
# 4   New York Yankees       nya         NYY           6
# 5   New York Yankees       nya         NYY           6
# 6   New York Yankees       nya         NYY           6
# 7   New York Yankees       nya         NYY           6
# 8   New York Yankees       nya         NYY           5
# 9   New York Yankees       nya         NYY           6
# 10  New York Yankees       nya         NYY           6
# 11  New York Yankees       nya         NYY           6
# 12  New York Yankees       nya         NYY           5
# 13  New York Yankees       nya         NYY           6
# 14  New York Yankees       nya         NYY           6
# 15  New York Yankees       nya         NYY           6
# 16  New York Yankees       nya         NYY           6
# 17  New York Yankees       nya         NYY           6
# 18  New York Yankees       nya         NYY           6
# 19  New York Yankees       nya         NYY           6
# 20  New York Yankees       nya         NYY           5
# 21  New York Yankees       nya         NYY           6
# 22  New York Yankees       nya         NYY           6
# 23  New York Yankees       nya         NYY           5
# 24  New York Yankees       nya         NYY           6
# 25  New York Yankees       nya         NYY           6
# 26  New York Yankees       nya         NYY           6
# 27  New York Yankees       nya         NYY           6
# 28  New York Yankees       nya         NYY           6
# 29  New York Yankees       nya         NYY           6
# 30  New York Yankees       nya         NYY           6
# 31  New York Yankees       nya         NYY           6
# 32  New York Yankees       nya         NYY           6
# 33  New York Yankees       nya         NYY           6
# 34  New York Yankees       nya         NYY           5
# 35  New York Yankees       nya         NYY           6
# 36  New York Yankees       nya         NYY           6
# 37  New York Yankees       nya         NYY           6
# 38  New York Yankees       nya         NYY           6
# 39  New York Yankees       nya         NYY           5
#
# [40 rows x 26 columns]

# %%
YANKEES_CURRENT_ROSTER.columns
# Out:
# Index(['college', 'end_date', 'pro_debut_date', 'status_code', 'name_full',
#        'name_display_first_last', 'birth_date', 'height_inches', 'team_id',
#        'name_last', 'bats', 'player_id', 'position_txt', 'primary_position',
#        'jersey_number', 'starter_sw', 'start_date', 'name_display_last_first',
#        'name_first', 'name_use', 'weight', 'throws', 'team_name', 'team_code',
#        'team_abbrev', 'height_feet'],
#       dtype='object')

# %%
YANKEES_CURRENT_ROSTER.loc[YANKEES_CURRENT_ROSTER['name_last'] == 'Judge']['player_id']
# Out:
# 19    592450
# Name: player_id, dtype: object

# %%
def teams_by_year(year):
    teams_url = MLB_URL + f'/named.team_all_season.bam?sport_code=%27mlb%27&all_star_sw=%27N%27&sort_order=name_asc&season=%27{year}%27'
    resp = requests.get(teams_url)
    teams_json = clean_json(resp)
    return DataFrame(teams_json['team_all_season']['queryResults']['row'])

# %%
# Specifically TEAMS by year!!! Not rosters on teams
teams_2020 = teams_by_year(2020)
teams_2020.head()
# Out:
#      venue_short sport_id league_abbrev team_id spring_league_id active_sw  \
# 0    Chase Field        1            NL     109              114         Y
# 1    Truist Park        1            NL     144              115         Y
# 2    Oriole Park        1            AL     110              115         Y
# 3    Fenway Park        1            AL     111              115         Y
# 4  Wrigley Field        1            NL     112              114         Y
#
#   division mlb_org_brief season first_year_of_play  ... address_city  \
# 0        W       D-backs   2020               1996  ...      Phoenix
# 1        E        Braves   2020               1871  ...      Atlanta
# 2        E       Orioles   2020               1901  ...    Baltimore
# 3        E       Red Sox   2020               1901  ...       Boston
# 4        C          Cubs   2020               1874  ...      Chicago
#
#   team_code mlb_org_abbrev address_intl time_zone_generic website_url  \
# 0       ari            ARI            N               MST
# 1       atl            ATL            N                ET
# 2       bal            BAL            N                ET
# 3       bos            BOS            N                ET
# 4       chn            CHC            N                CT
#
#       sport_code_display home_opener_time mlb_org_short league_id
# 0  Major League Baseball       9:40:00 PM       Arizona       104
# 1  Major League Baseball       7:10:00 PM       Atlanta       104
# 2  Major League Baseball       7:35:00 PM     Baltimore       103
# 3  Major League Baseball       7:30:00 PM        Boston       103
# 4  Major League Baseball       7:10:00 PM      Chi Cubs       104
#
# [5 rows x 64 columns]

# %%
TEAMS_1900 = teams_by_year(1900)

# %%
teams_2020.columns
# Out:
# Index(['venue_short', 'sport_id', 'league_abbrev', 'team_id',
#        'spring_league_id', 'active_sw', 'division', 'mlb_org_brief', 'season',
#        'first_year_of_play', 'state', 'name_short', 'bis_team_code',
#        'venue_id', 'name_display_short', 'name_display_long',
#        'name_display_brief', 'sport_code_name', 'spring_league', 'league',
#        'division_id', 'sport_code', 'time_zone_num', 'mlb_org',
#        'name_display_full', 'all_star_sw', 'division_abbrev', 'name',
#        'home_opener', 'phone_number', 'address_zip', 'time_zone_text',
#        'venue_name', 'division_full', 'franchise_code', 'city',
#        'time_zone_alt', 'address_state', 'name_abbrev', 'store_url',
#        'file_code', 'address_line3', 'address_line2', 'address_province',
#        'mlb_org_id', 'address_line1', 'spring_league_full',
#        'spring_league_abbrev', 'last_year_of_play', 'address', 'league_full',
#        'address_country', 'base_url', 'time_zone', 'address_city', 'team_code',
#        'mlb_org_abbrev', 'address_intl', 'time_zone_generic', 'website_url',
#        'sport_code_display', 'home_opener_time', 'mlb_org_short', 'league_id'],
#       dtype='object')

# %%
rosters_all = pd.concat([roster40(x) for x in teams_2020['mlb_org_id']], ignore_index=True)
rosters_all.columns
# Out:
# Index(['college', 'end_date', 'pro_debut_date', 'status_code', 'name_full',
#        'name_display_first_last', 'birth_date', 'height_inches', 'team_id',
#        'name_last', 'bats', 'player_id', 'position_txt', 'primary_position',
#        'jersey_number', 'starter_sw', 'start_date', 'name_display_last_first',
#        'name_first', 'name_use', 'weight', 'throws', 'team_name', 'team_code',
#        'team_abbrev', 'height_feet'],
#       dtype='object')

# %%
len(rosters_all.loc[rosters_all['college'] != ''])
# Out:
# 601

# %% [markdown]
# Note the index on each ```roster40``` DataFrame isn't meaningful -- it's just a list of numbers 0 to 39 -- which is why we set the ```ignore_index``` to ```True```. This resets the index on the final, combined DataFrame.
# Presumably, a player can only be on one team, and there shouldn't be any duplicates by player_id

# %%
rosters_all['player_id'].duplicated().any()
# Out:
# False

# %% [markdown]
# Perfect. Let's use ```player_id``` for our index value then.

# %%
rosters_all.set_index('player_id', inplace=True)
# rosters_all.columns

# %%
rosters_all.loc[rosters_all['name_full'] == 'Ford, Mike']
# Out:
#              college end_date       pro_debut_date status_code   name_full  \
# player_id
# 645801     Princeton           2019-04-18T00:00:00           A  Ford, Mike
#
#           name_display_first_last           birth_date height_inches team_id  \
# player_id
# 645801                  Mike Ford  1992-07-04T00:00:00             0     144
#
#           name_last  ...           start_date name_display_last_first  \
# player_id            ...
# 645801         Ford  ...  2022-06-10T00:00:00              Ford, Mike
#
#           name_first name_use weight throws       team_name team_code  \
# player_id
# 645801       Michael     Mike    225      R  Atlanta Braves       atl
#
#           team_abbrev height_feet
# player_id
# 645801            ATL           6
#
# [1 rows x 25 columns]

# %% [markdown]
# Now that we've got ```player_ids``` for every player in the game, we're on to step(3): querying individual stats. The format is similar:

# %%
# Change the year in the 'season=' argument to see stats from different years
def season_hitting_data(player_id, season=2020):
    player_url = MLB_URL + f'/named.sport_hitting_tm.bam?league_list_id=%27mlb%27&game_type=%27R%27&season=%27{season}%27&player_id=%27{player_id}%27'
    resp = requests.get(player_url)
    return clean_json(resp)['sport_hitting_tm']['queryResults']['row']

# %% [markdown]
# The function only seems to work on certain players (hitters mainly)

# %%
# Juan Soto
season_hitting_data(665742)
# Out:
# {'sport_id': '1',
#  'league_short': 'National',
#  'hr': '13',
#  'team_id': '120',
#  'season': '2020',
#  'ab': '154',
#  'hldr': '27',
#  'league': 'NL',
#  'sport_code': 'mlb',
#  'ao': '23',
#  'slg': '.695',
#  'team_full': 'Washington Nationals',
#  'ops': '1.185',
#  'team_abbrev': 'WSH',
#  'hbp': '1',
#  'rbi': '37',
#  'go_ao': '2.13',
#  'hfly': '9',
#  'lob': '54',
#  'xbh': '27',
#  'end_date': '2021-04-20T00:00:00',
#  'bb': '41',
#  'np': '827',
#  'hgnd': '18',
#  'roe': '3',
#  'sb': '6',
#  'player_id': '665742',
#  'avg': '.351',
#  'sf': '0',
#  'sac': '0',
#  'wo': '0',
#  'team_short': 'Washington',
#  'hpop': '0',
#  'so': '28',
#  'gidp_opp': '29',
#  'gidp': '1',
#  'ppa': '4.22',
#  'd': '14',
#  'tpa': '196',
#  'league_full': 'National League',
#  'g': '47',
#  'h': '54',
#  'ibb': '12',
#  'go': '49',
#  'team_seq': '1.0',
#  'tb': '107',
#  'cs': '2',
#  'r': '39',
#  't': '0',
#  'babip': '.363',
#  'obp': '.490',
#  'sport': 'MLB',
#  'league_id': '104'}

# %%
# Change the year in the 'season=' argument to see stats from different years
def season_hitting_row(player_id, season=2020):
    player_url = MLB_URL + f'/named.sport_hitting_tm.bam?league_list_id=%27mlb%27&game_type=%27R%27&player_id=%27{player_id}%27&season=%27{season}%27'
    resp = requests.get(player_url)
    # .T returns the transpose!
    # .to_frame() turns a Series to DataFrame object
    return Series(clean_json(resp)['sport_hitting_tm']['queryResults']['row']).to_frame(player_id).T

# %%
# Juan Soto, 2020 stats
season_hitting_row(665742)
# Out:
#        sport_id league_short  hr team_id season   ab hldr league sport_code  \
# 665742        1     National  13     120   2020  154   27     NL        mlb
#
#         ao  ...  go team_seq   tb cs   r  t babip   obp sport league_id
# 665742  23  ...  49      1.0  107  2  39  0  .363  .490   MLB       104
#
# [1 rows x 53 columns]

# %%
# Juan Soto, 2022 stats
season_hitting_row(665742, season=2022)
# Out:
#        sport_id league_short  hr team_id season   ab hldr league sport_code  \
# 665742        1     National  14     120   2022  248   18     NL        mlb
#
#         ao  ...  go team_seq   tb cs   r  t babip   obp sport league_id
# 665742  60  ...  89      1.0  107  2  38  0  .207  .365   MLB       104
#
# [1 rows x 53 columns]

# %%
def season_hitting_row2(player_id, season=2020):
    player_url = MLB_URL + f'/named.sport_hitting_tm.bam?league_list_id=%27mlb%27&game_type=%27R%27&player_id=%27{player_id}%27&season=%27{season}%27'
    resp = requests.get(player_url)
    qr = clean_json(resp)['sport_hitting_tm']['queryResults']
    
    if 'row' in qr: 
        # .T returns the transpose!
        # .to_frame() turns a Series to DataFrame object
        return Series(qr['row']).to_frame(player_id).T
    else:
        return DataFrame()

# %%
season_hitting_row2(000000) # not a real player
# produces an empty DF
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# The second issue is if we get more than one row back, which happens if a player was traded in season (technically this data is at the player-season-team level). For example, Mike Ford (```player_id``` 645801) was traded mid 2022 from the Giants to the Mariners.

# %%
season_hitting_row2(645801, season=2022) #ford, traded midseason
# Out:
#                                                         0  \
# 645801  {'sport_id': '1', 'league_short': 'National', ...
#
#                                                         1
# 645801  {'sport_id': '1', 'league_short': 'American', ...

# %%
season_hitting_data(645801, season=2022)
# Out:
# [{'sport_id': '1',
#   'league_short': 'National',
#   'hr': '0',
#   'team_id': '137',
#   'season': '2022',
#   'ab': '4',
#   'hldr': '1',
#   'league': 'NL',
#   'sport_code': 'mlb',
#   'ao': '3',
#   'slg': '.250',
#   'team_full': 'San Francisco Giants',
#   'ops': '.500',
#   'team_abbrev': 'SF',
#   'hbp': '0',
#   'rbi': '2',
#   'go_ao': '0.00',
#   'hfly': '0',
#   'lob': '1',
#   'xbh': '0',
#   'end_date': '2022-05-12T00:00:00',
#   'bb': '0',
#   'np': '13',
#   'hgnd': '0',
#   'roe': '0',
#   'sb': '0',
#   'player_id': '645801',
#   'avg': '.250',
#   'sf': '0',
#   'sac': '0',
#   'wo': '0',
#   'team_short': 'San Francisco',
#   'hpop': '0',
#   'so': '0',
#   'gidp_opp': '0',
#   'gidp': '0',
#   'ppa': '3.25',
#   'd': '0',
#   'tpa': '4',
#   'league_full': 'National League',
#   'g': '1',
#   'h': '1',
#   'ibb': '0',
#   'go': '0',
#   'team_seq': '2.0',
#   'tb': '1',
#   'cs': '0',
#   'r': '0',
#   't': '0',
#   'babip': '.250',
#   'obp': '.250',
#   'sport': 'MLB',
#   'league_id': '104'},
#  {'sport_id': '1',
#   'league_short': 'American',
#   'hr': '0',
#   'team_id': '136',
#   'season': '2022',
#   'ab': '29',
#   'hldr': '3',
#   'league': 'AL',
#   'sport_code': 'mlb',
#   'ao': '4',
#   'slg': '.207',
#   'team_full': 'Seattle Mariners',
#   'ops': '.575',
#   'team_abbrev': 'SEA',
#   'hbp': '1',
#   'rbi': '3',
#   'go_ao': '2.00',
#   'hfly': '0',
#   'lob': '9',
#   'xbh': '1',
#   'end_date': '2022-06-10T00:00:00',
#   'bb': '8',
#   'np': '170',
#   'hgnd': '2',
#   'roe': '0',
#   'sb': '0',
#   'player_id': '645801',
#   'avg': '.172',
#   'sf': '0',
#   'sac': '0',
#   'wo': '0',
#   'team_short': 'Seattle',
#   'hpop': '0',
#   'so': '12',
#   'gidp_opp': '3',
#   'gidp': '0',
#   'ppa': '4.47',
#   'd': '1',
#   'tpa': '38',
#   'league_full': 'American League',
#   'g': '16',
#   'h': '5',
#   'ibb': '0',
#   'go': '8',
#   'team_seq': '1.0',
#   'tb': '6',
#   'cs': '0',
#   'r': '1',
#   't': '0',
#   'babip': '.294',
#   'obp': '.368',
#   'sport': 'MLB',
#   'league_id': '103'}]

# %% [markdown]
# We can it's returning a *list* of hitting dicts. Whereas in the regular (non traded) case it's returning just the one dict. Let's handle this by (1) checking on what we get back from theJSON, and (2) wrapping it inside a list in the one player case sp we can treat both cases the same.
# The relevant parts are in the two ```if``` statements

# %%
def season_hitting_rows(player_id, season = 2020):
    player_url = MLB_URL + f'/named.sport_hitting_tm.bam?league_list_id=%27mlb%27&game_type=%27R%27&season=%27{season}%27&player_id=%27{player_id}%27'
    resp = requests.get(player_url)
    qr = clean_json(resp)['sport_hitting_tm']['queryResults']
    
    if 'row' in qr:
        raw_data = qr['row']
        if type(raw_data) is dict:
            raw_data = [raw_data]
        return DataFrame(raw_data)
    else:
        return DataFrame()

# %%
# Mike Ford's stats for each team , nice. 
season_hitting_rows(645801, season=2022)
# Out:
#   sport_id league_short hr team_id season  ab hldr league sport_code ao  ...  \
# 0        1     National  0     137   2022   4    1     NL        mlb  3  ...
# 1        1     American  0     136   2022  29    3     AL        mlb  4  ...
#
#   go team_seq tb cs  r  t babip   obp sport league_id
# 0  0      2.0  1  0  0  0  .250  .250   MLB       104
# 1  8      1.0  6  0  1  0  .294  .368   MLB       103
#
# [2 rows x 53 columns]

# %%
# Now, let's make sure this works for our regular case
season_hitting_rows(665742, season=2022) # Juan Soto, 2022 stats
# Out:
#   sport_id league_short  hr team_id season   ab hldr league sport_code  ao  \
# 0        1     National  14     120   2022  248   18     NL        mlb  60
#
#    ...  go team_seq   tb cs   r  t babip   obp sport league_id
# 0  ...  89      1.0  107  2  38  0  .207  .365   MLB       104
#
# [1 rows x 53 columns]

# %% [markdown]
# Now we can go through our full roster, finding each's player's ```player_id```, and using to query thier 2020 hitting stats and bind them together

# %%
rosters_all.loc[(rosters_all['position_txt'] != 'P') & (rosters_all['name_last'] == 'Judge')]
# Out:
#                 college end_date       pro_debut_date status_code  \
# player_id
# 592450     Fresno State           2016-08-13T00:00:00           A
#
#               name_full name_display_first_last           birth_date  \
# player_id
# 592450     Judge, Aaron             Aaron Judge  1992-04-26T00:00:00
#
#           height_inches team_id name_last  ...           start_date  \
# player_id                                  ...
# 592450                7     147     Judge  ...  2016-08-13T00:00:00
#
#           name_display_last_first name_first name_use weight throws  \
# player_id
# 592450               Judge, Aaron      Aaron    Aaron    282      R
#
#                   team_name team_code team_abbrev height_feet
# player_id
# 592450     New York Yankees       nya         NYY           6
#
# [1 rows x 25 columns]

# %%
hitting_2022 = pd.concat([season_hitting_rows(x, season=2022) for x in rosters_all.index], ignore_index=True)

# %%
for x in rosters_all.index:
    if x == '592450':
        print(type(x))
# Out:
# <class 'str'>

# %%
hitting_2022.columns
# Out:
# Index(['sport_id', 'league_short', 'hr', 'team_id', 'season', 'ab', 'hldr',
#        'league', 'sport_code', 'ao', 'slg', 'team_full', 'ops', 'team_abbrev',
#        'hbp', 'rbi', 'go_ao', 'hfly', 'lob', 'xbh', 'end_date', 'bb', 'np',
#        'hgnd', 'roe', 'sb', 'player_id', 'avg', 'sf', 'sac', 'wo',
#        'team_short', 'hpop', 'so', 'gidp_opp', 'gidp', 'ppa', 'd', 'tpa',
#        'league_full', 'g', 'h', 'ibb', 'go', 'team_seq', 'tb', 'cs', 'r', 't',
#        'babip', 'obp', 'sport', 'league_id'],
#       dtype='object')

# %%
for x in hitting_2022['team_abbrev']:
    print(x)
# Out:
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# ARI
# PIT
# ARI
# ARI
# ARI
# ARI
# ATL
# ATL
# ATL
# ATL
# ATL
# ATL
# SF
# SEA
# ATL
# ATL
# ATL
# ATL
# ATL
# ATL
# ATL
# STL
# ATL
# ATL
# BOS
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BAL
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# BOS
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CHC
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CWS
# CIN
# CIN
# CIN
# CIN
# SEA
# SF
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# NYM
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CIN
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# CLE
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# COL
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# DET
# HOU
# HOU
# HOU
# HOU
# HOU
# HOU
# SF
# HOU
# HOU
# HOU
# HOU
# HOU
# HOU
# HOU
# HOU
# HOU
# LAA
# HOU
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# KC
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAA
# LAD
# LAD
# LAD
# LAD
# LAD
# LAD
# LAD
# LAD
# LAD
# LAD
# LAD
# LAD
# LAD
# LAD
# SD
# LAD
# LAD
# LAD
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# MIA
# SF
# MIA
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIL
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# MIN
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# NYM
# KC
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# NYY
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# OAK
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PHI
# PIT
# PIT
# PIT
# CLE
# PIT
# PIT
# PIT
# PIT
# PIT
# PIT
# TOR
# PIT
# PIT
# PIT
# PIT
# PIT
# PIT
# PIT
# PIT
# PIT
# PIT
# PIT
# PIT
# PIT
# SD
# ARI
# SD
# SD
# SD
# SD
# SD
# SD
# SD
# SD
# SD
# SD
# SD
# SD
# SD
# SD
# SD
# SF
# SF
# SF
# SF
# SF
# SF
# SF
# SF
# SF
# SF
# SF
# SF
# SF
# SF
# SF
# SEA
# SF
# SF
# SF
# SEA
# SEA
# ARI
# SEA
# SEA
# SEA
# SEA
# SEA
# SEA
# SEA
# SEA
# SF
# SEA
# SEA
# SEA
# SEA
# SEA
# SEA
# SEA
# SEA
# SEA
# SEA
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# STL
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TB
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TEX
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# TOR
# WSH
# WSH
# WSH
# WSH
# WSH
# WSH
# WSH
# WSH
# WSH
# WSH
# WSH
# WSH
# WSH
# WSH

# %%
rosters_all['name_full']
# Out:
# player_id
# 666179            Beer, Seth
# 518516    Bumgarner, Madison
# 605200          Davies, Zach
# 666818           Frias, Luis
# 643316             Fry, Paul
#                  ...
# 665742            Soto, Juan
# 544931    Strasburg, Stephen
# 676194    Tetreault, Jackson
# 657041          Thomas, Lane
# 607179         Weems, Jordan
# Name: name_full, Length: 1204, dtype: object

# %% [markdown]
# ### I found out the ```hr``` and ```player_id``` columns was a string when I went to sort by highest homeruns so far because I knew Aaron Judge had 25 at the time of this (6/20/2022) so had to convert it to an int in order to be able to sort the values

# %%
hitting_2022['hr'] = (hitting_2022['hr']).astype(int)
(hitting_2022.loc[hitting_2022['team_abbrev'] == 'NYY', ['player_id', 'avg', 'obp', 'slg', 'ops', 'hr']]).sort_values(by='hr', ascending=False)
# Out:
#     player_id   avg   obp   slg    ops  hr
# 357    592450  .302  .379  .663  1.042  27
# 361    519203  .231  .336  .510   .846  19
# 362    519317  .245  .333  .480   .813  14
# 363    650402  .260  .309  .512   .821  13
# 353    608336  .180  .295  .360   .655   9
# 350    572761  .265  .375  .824  1.199   6
# 351    518626  .233  .327  .386   .714   6
# 359    518934  .260  .346  .399   .746   6
# 364    624431  .283  .339  .478   .817   6
# 356    543309  .176  .222  .324   .546   4
# 354    503556  .244  .300  .390   .690   2
# 355    543305  .232  .344  .288   .633   2
# 360    641796  .231  .333  .462   .795   1
# 349    609280  .268  .279  .317   .596   0
# 352    664314  .000  .083  .000   .083   0
# 358    643396  .269  .322  .321   .643   0

# %%
hitting_2022.loc[hitting_2022['team_abbrev'] == 'WSH']
# Out:
#     sport_id league_short  hr team_id season   ab hldr league sport_code  ao  \
# 550        1     National   3     120   2022   72    5     NL        mlb  18
# 551        1     National   0     120   2022   30    3     NL        mlb   7
# 552        1     National  11     120   2022  254   35     NL        mlb  63
# 553        1     National   7     120   2022  242   28     NL        mlb  52
# 554        1     National   0     120   2022  118   15     NL        mlb  36
# 555        1     National   0     120   2022   25    0     NL        mlb   4
# 556        1     National   6     120   2022  266   39     NL        mlb  76
# 557        1     National   2     120   2022   82   13     NL        mlb  16
# 558        1     National   0     120   2022  293   38     NL        mlb  79
# 559        1     National   4     120   2022  178   28     NL        mlb  26
# 560        1     National   1     120   2022  159   15     NL        mlb  41
# 561        1     National   2     120   2022  201   37     NL        mlb  66
# 562        1     National  14     120   2022  248   18     NL        mlb  60
# 563        1     National   8     120   2022  195   17     NL        mlb  52
#
#      ...  go team_seq   tb cs   r  t babip   obp sport league_id
# 550  ...  16      1.0   25  0   8  0  .261  .288   MLB       104
# 551  ...  10      1.0    6  0   1  0  .227  .194   MLB       104
# 552  ...  79      1.0  120  1  37  1  .311  .380   MLB       104
# 553  ...  71      1.0   92  0  32  0  .301  .332   MLB       104
# 554  ...  26      1.0   34  1  11  2  .295  .264   MLB       104
# 555  ...  12      1.0    2  0   2  0  .125  .115   MLB       104
# 556  ...  73      1.0  101  0  22  0  .294  .280   MLB       104
# 557  ...  22      1.0   38  2   9  0  .397  .341   MLB       104
# 558  ...  80      1.0   98  2  39  2  .331  .314   MLB       104
# 559  ...  59      1.0   70  1  18  0  .341  .314   MLB       104
# 560  ...  42      1.0   50  0  24  1  .327  .303   MLB       104
# 561  ...  63      1.0   70  0  18  0  .277  .314   MLB       104
# 562  ...  89      1.0  107  2  38  0  .207  .365   MLB       104
# 563  ...  44      1.0   81  0  27  1  .284  .303   MLB       104
#
# [14 rows x 53 columns]

# %% [markdown]
# ### Awesome, now we could run this on all players(not just the top 100) or all years if we want too. If we look at the other endpoints, there's also career hitting stats as well as (season and career) pitching stats.
#
# ##### From the ```season_hitting_rows``` function, the next cell of the ```if 'row' in qr``` part is in its own separate helper function.

# %%
def qr_to_df(qr):
    if 'row' in qr:
        raw_data = qr['row']
        if type(raw_data) is dict:
            raw_data = [raw_data]
        return DataFrame(raw_data)
    else:
        return DataFrame()

# %%
# rewritten with the new 'qr_to_df' function
def season_hitting_rows(player_id, season=2020):
    player_url = MLB_URL + f'/named.sport_hitting_tm.bam?league_list_id=%27mlb%27&game_type=%27R%27&season=%27{season}%27&player_id=%27{player_id}%27'
    resp = requests.get(player_url)
    qr = clean_json(resp)['sport_hitting_tm']['queryResults']
    return qr_to_df(qr)

# %%
def season_pitching_rows(player_id, season=2020):
    player_url = MLB_URL + f'/named.sport_pitching_tm.bam?league_list_id=%27mlb%27&game_type=%27R%27&season={season}&player_id={player_id}'
    resp = requests.get(player_url)
    qr = clean_json(resp)['sport_pitching_tm']['queryResults']
    return qr_to_df(qr)

# %%
def career_hitting_rows(player_id):
    player_url = MLB_URL + f'/named.sport_career_hitting.bam?league_list_id=%27mlb%27&game_type=%27R%27&player_id={player_id}'
    resp = requests.get(player_url)
    qr = clean_json(resp)['sport_career_hitting']['queryResults']
    return qr_to_df(qr)

# %%
def career_pitching_rows(player_id):
    player_url = MLB_URL + f'/named.sport_career_pitching.bam?league_list_id=%27mlb%27&game_type=%27R%27&player_id={player_id}'
    resp = requests.get(player_url)
    qr = clean_json(resp)['sport_career_pitching']['queryResults']
    return qr_to_df(qr)

# %% [markdown]
# ### Next, we call them. I'm going to skip the rewritten function```season_hitting_rows``` here

# %%
hitting_2022 = pd.concat([season_hitting_rows(x, season=2022) for x in rosters_all.index], ignore_index=True)
hitting_2022
# Out:
#     sport_id league_short  hr team_id season   ab hldr league sport_code  ao  \
# 0          1     National   1     109   2022   81   12     NL        mlb  18
# 1          1     National   0     109   2022   41    4     NL        mlb   8
# 2          1     National   0     109   2022   24    0     NL        mlb   5
# 3          1     National   0     109   2022   80    4     NL        mlb  13
# 4          1     National   2     109   2022  101    9     NL        mlb  18
# ..       ...          ...  ..     ...    ...  ...  ...    ...        ...  ..
# 559        1     National   4     120   2022  178   28     NL        mlb  26
# 560        1     National   1     120   2022  159   15     NL        mlb  41
# 561        1     National   2     120   2022  201   37     NL        mlb  66
# 562        1     National  14     120   2022  248   18     NL        mlb  60
# 563        1     National   8     120   2022  195   17     NL        mlb  52
#
#      ...  go team_seq   tb cs   r  t babip   obp sport league_id
# 0    ...  23      1.0   23  0   4  0  .281  .301   MLB       104
# 1    ...  10      1.0   10  0   3  0  .346  .319   MLB       104
# 2    ...  15      1.0    2  0   2  0  .100  .154   MLB       104
# 3    ...  26      1.0   17  0   6  0  .283  .244   MLB       104
# 4    ...  27      1.0   32  0  10  2  .262  .308   MLB       104
# ..   ...  ..      ...  ... ..  .. ..   ...   ...   ...       ...
# 559  ...  59      1.0   70  1  18  0  .341  .314   MLB       104
# 560  ...  42      1.0   50  0  24  1  .327  .303   MLB       104
# 561  ...  63      1.0   70  0  18  0  .277  .314   MLB       104
# 562  ...  89      1.0  107  2  38  0  .207  .365   MLB       104
# 563  ...  44      1.0   81  0  27  1  .284  .303   MLB       104
#
# [564 rows x 53 columns]

# %%
pitching_2022 = pd.concat([season_pitching_rows(x, season=2022) for x in rosters_all.index], ignore_index=True)
pitching_2022
# Out:
#     sport_id bqs league_short  hr team_id  whip   pip season   rs9   ab  ...  \
# 0          1   0     National  12     109  1.37  17.2   2022  3.15  297  ...
# 1          1   0     National  10     109  1.20  16.6   2022  3.12  279  ...
# 2          1   2     National   0     109  2.83  23.7   2022  4.50   27  ...
# 3          1   0     American   1     110  1.33  17.1   2022  3.00   43  ...
# 4          1   0     National   0     109  4.00  27.0   2022  0.00    5  ...
# ..       ...  ..          ...  ..     ...   ...   ...    ...   ...  ...  ...
# 627        1   2     National   7     120  1.41  15.2   2022  3.58  131  ...
# 628        1   3     National   6     120  1.33  15.9   2022  4.78  101  ...
# 629        1   0     National   1     120  2.14  17.8   2022  3.86   20  ...
# 630        1   0     National   3     120  1.64  16.5   2022  9.82   48  ...
# 631        1   0     National   2     120  2.21  24.2   2022  1.42   26  ...
#
#      w babip    bb9 hb pk   obp sport league_id  db tr
# 0    3  .289   2.78  2  0  .323   MLB       104  21  2
# 1    2  .258   3.00  2  0  .297   MLB       104  12  1
# 2    0  .417  10.50  1  0  .514   MLB       104   3  1
# 3    0  .258   5.25  2  0  .340   MLB       103   1  1
# 4    0  .667  18.00  0  0  .571   MLB       104   0  0
# ..  ..   ...    ... .. ..   ...   ...       ...  .. ..
# 627  1  .311   1.93  4  0  .347   MLB       104   2  0
# 628  2  .217   3.76  0  1  .313   MLB       104   3  0
# 629  0  .500   3.86  1  0  .478   MLB       104   3  0
# 630  1  .286   2.45  0  0  .346   MLB       104   1  0
# 631  0  .333   8.53  0  0  .438   MLB       104   1  0
#
# [632 rows x 79 columns]

# %%
hitting_career = pd.concat([career_hitting_rows(x) for x in rosters_all.index], ignore_index=True)
hitting_career
# Out:
#       bb sport_id    np hgnd roe   hr team_count  sb player_id   avg  ...  t  \
# 0      9        1   370    4   0    2          1   0    666179  .233  ...  0
# 1     49        1  2765   32   4   19          2   0    518516  .172  ...  0
# 2      9        1   947   14   5    0          2   0    605200  .126  ...  0
# 3      0        1     0    0   0    0          1   0    666818        ...  0
# 4      0        1     0    0   0    0          1   0    643316        ...  0
# ..   ...      ...   ...  ...  ..  ...        ...  ..       ...   ...  ... ..
# 993   22        1  1123   17   2    6          2   3    660688  .259  ...  0
# 994  430        1  9551  187  13  112          1  37    665742  .289  ...  8
# 995   24        1  1895   30   7    4          1   0    544931  .152  ...  0
# 996   64        1  2321   36   6   20          2   8    657041  .232  ...  4
# 997    0        1     0    0   0    0          2   0    607179        ...  0
#
#     hbp  rbi babip go_ao hfly   obp sport  lob  xbh
# 0     3   12  .306  1.15    2  .320   MLB   35    6
# 1     2   65  .269  1.43   23  .232   MLB  355   38
# 2     0    9  .201  2.32    0  .161   MLB   98    4
# 3     0    0                0         MLB    0    0
# 4     0    0                0         MLB    0    0
# ..   ..  ...   ...   ...  ...   ...   ...  ...  ...
# 993   4   31  .276  0.89   11  .318   MLB  152   22
# 994   8  343  .313  1.47  118  .423   MLB  807  223
# 995   1   29  .223  4.42    7  .198   MLB  230   14
# 996   3   71  .280  0.97   26  .322   MLB  227   50
# 997   0    0                0         MLB    0    0
#
# [998 rows x 43 columns]

# %%
pitching_career = pd.concat([career_pitching_rows(x) for x in rosters_all.index], ignore_index=True)
pitching_career
# Out:
#     sport_id bqs   hr  whip   pip   rs9    ab   qs hldr      ip  ...      s  \
# 0          1  36  241  1.13  15.7  4.36  7935  202  903  2108.1  ...  21880
# 1          1  32  114  1.32  16.4  4.83  3461   60  484   906.2  ...   9214
# 2          1   2    0  2.57  22.5  2.89    37    0    5     9.1  ...    117
# 3          1  45   15  1.43  18.0  4.31   669    0   66   177.1  ...   1929
# 4          1  10   43  1.18  16.8  3.97  1279   29  137   344.1  ...   3667
# ..       ...  ..  ...   ...   ...   ...   ...  ...  ...     ...  ...    ...
# 683        1  41  111  1.25  15.5  4.09  2728   33  319   714.1  ...   7239
# 684        1   3   22  1.44  16.2  4.60   343    2   35    88.0  ...    898
# 685        1  21  149  1.10  15.9  5.12  5449  152  597  1470.0  ...  15291
# 686        1   0    3  1.64  16.5  9.82    48    1    7    11.0  ...    112
# 687        1   1    5  1.65  19.6  2.42    99    0    7    26.0  ...    290
#
#        w babip    bb9  hb  pk   obp sport   db  tr
# 0    130  .286   2.15  81  30  .288   MLB  393  38
# 1     58  .291   2.97  28   6  .322   MLB  171  23
# 2      0  .375  11.57   1   0  .490   MLB    4   1
# 3      7  .307   4.92  17   1  .345   MLB   23   2
# 4     14  .275   3.37  20   1  .298   MLB   59   3
# ..   ...   ...    ...  ..  ..   ...   ...  ...  ..
# 683   34  .278   2.49  36   2  .310   MLB  125   6
# 684    5  .248   3.68   6   1  .344   MLB   12   2
# 685  113  .296   2.41  53   1  .281   MLB  223  23
# 686    1  .286   2.45   0   0  .346   MLB    1   0
# 687    0  .297   6.58   1   0  .367   MLB    4   1
#
# [688 rows x 69 columns]

# %%
basic_hitting_stats = hitting_2022[['player_id', 'avg', 'obp', 'slg', 'ops', 'hr']]
basic_hitting_stats
# Out:
#     player_id   avg   obp   slg   ops  hr
# 0      666179  .210  .301  .284  .585   1
# 1      606993  .220  .319  .244  .563   0
# 2      660634  .083  .154  .083  .237   0
# 3      645444  .188  .244  .213  .457   0
# 4      669450  .178  .308  .317  .625   2
# ..        ...   ...   ...   ...   ...  ..
# 559    628450  .270  .314  .393  .707   4
# 560    645302  .239  .303  .314  .617   1
# 561    660688  .254  .314  .348  .662   2
# 562    665742  .214  .365  .431  .796  14
# 563    657041  .236  .303  .415  .718   8
#
# [564 rows x 6 columns]

# %%
rosters_all_new_index = rosters_all.reset_index()
rosters_all_new_index
# Out:
#      player_id                   college end_date       pro_debut_date  \
# 0       666179                   Clemson           2021-09-10T00:00:00
# 1       518516                                     2009-09-08T00:00:00
# 2       605200                                     2015-09-02T00:00:00
# 3       666818                                     2021-09-19T00:00:00
# 4       643316   St. Clair County CC, MI           2018-06-29T00:00:00
# ...        ...                       ...      ...                  ...
# 1199    665742                                     2018-05-15T00:00:00
# 1200    544931           San Diego State           2010-06-08T00:00:00
# 1201    676194  State College of Florida           2022-06-14T00:00:00
# 1202    657041                                     2019-04-17T00:00:00
# 1203    607179                                     2020-07-28T00:00:00
#
#      status_code           name_full name_display_first_last  \
# 0             RM          Beer, Seth               Seth Beer
# 1              A  Bumgarner, Madison       Madison Bumgarner
# 2              A        Davies, Zach             Zach Davies
# 3             RM         Frias, Luis              Luis Frias
# 4             RM           Fry, Paul                Paul Fry
# ...          ...                 ...                     ...
# 1199           A          Soto, Juan               Juan Soto
# 1200         D15  Strasburg, Stephen       Stephen Strasburg
# 1201           A  Tetreault, Jackson       Jackson Tetreault
# 1202           A        Thomas, Lane             Lane Thomas
# 1203          RM       Weems, Jordan            Jordan Weems
#
#                birth_date height_inches team_id  ...           start_date  \
# 0     1996-09-18T00:00:00             3     109  ...  2021-09-10T00:00:00
# 1     1989-08-01T00:00:00             4     109  ...  2019-12-17T00:00:00
# 2     1993-02-07T00:00:00             0     109  ...  2022-03-24T00:00:00
# 3     1998-05-23T00:00:00             3     109  ...  2020-11-20T00:00:00
# 4     1992-07-26T00:00:00             0     109  ...  2022-05-18T00:00:00
# ...                   ...           ...     ...  ...                  ...
# 1199  1998-10-25T00:00:00             2     120  ...  2018-05-20T00:00:00
# 1200  1988-07-20T00:00:00             5     120  ...  2019-12-09T00:00:00
# 1201  1996-06-03T00:00:00             5     120  ...  2022-06-14T00:00:00
# 1202  1995-08-23T00:00:00             0     120  ...  2021-07-30T00:00:00
# 1203  1992-11-07T00:00:00             4     120  ...  2022-05-31T00:00:00
#
#      name_display_last_first name_first name_use weight throws  \
# 0                 Beer, Seth       Seth     Seth    213      R
# 1         Bumgarner, Madison    Madison  Madison    257      L
# 2               Davies, Zach    Zachary     Zach    180      R
# 3                Frias, Luis       Luis     Luis    245      R
# 4                  Fry, Paul       Paul     Paul    205      L
# ...                      ...        ...      ...    ...    ...
# 1199              Soto, Juan       Juan     Juan    224      L
# 1200      Strasburg, Stephen    Stephen  Stephen    239      R
# 1201      Tetreault, Jackson    Jackson  Jackson    189      R
# 1202            Thomas, Lane       Lane     Lane    191      R
# 1203           Weems, Jordan     Jordan   Jordan    209      R
#
#                  team_name team_code team_abbrev height_feet
# 0     Arizona Diamondbacks       ari         ARI           6
# 1     Arizona Diamondbacks       ari         ARI           6
# 2     Arizona Diamondbacks       ari         ARI           6
# 3     Arizona Diamondbacks       ari         ARI           6
# 4     Arizona Diamondbacks       ari         ARI           6
# ...                    ...       ...         ...         ...
# 1199  Washington Nationals       was         WSH           6
# 1200  Washington Nationals       was         WSH           6
# 1201  Washington Nationals       was         WSH           6
# 1202  Washington Nationals       was         WSH           6
# 1203  Washington Nationals       was         WSH           6
#
# [1204 rows x 26 columns]

# %%
new_basic_hitting_stats = pd.merge(basic_hitting_stats, rosters_all_new_index[['player_id', 'name_full', 'team_abbrev']])

# %%
new_basic_hitting_stats['hr'] = (new_basic_hitting_stats['hr']).astype(int)
new_basic_hitting_stats['ops'] = (new_basic_hitting_stats['ops']).astype(float)
new_basic_hitting_stats['slg'] = [float(x) if x != '.---' else .000 for x in new_basic_hitting_stats['slg']]
new_basic_hitting_stats['avg'] = [float(x) if x != '.---' else .000 for x in new_basic_hitting_stats['avg']]
new_basic_hitting_stats['player_id'] = (new_basic_hitting_stats['player_id']).astype(int)
(new_basic_hitting_stats.loc[new_basic_hitting_stats['team_abbrev'] == 'NYY']).sort_values(by='ops', ascending =False)
# Out:
#      player_id    avg   obp    slg    ops  hr            name_full team_abbrev
# 350     572761  0.265  .375  0.824  1.199   6      Carpenter, Matt         NYY
# 357     592450  0.302  .379  0.663  1.042  27         Judge, Aaron         NYY
# 361     519203  0.231  .336  0.510  0.846  19       Rizzo, Anthony         NYY
# 363     650402  0.260  .309  0.512  0.821  13      Torres, Gleyber         NYY
# 364     624431  0.283  .339  0.478  0.817   6        Trevino, Jose         NYY
# 362     519317  0.245  .333  0.480  0.813  14   Stanton, Giancarlo         NYY
# 360     641796  0.231  .333  0.462  0.795   1        Locastro, Tim         NYY
# 359     518934  0.260  .346  0.399  0.746   6         LeMahieu, DJ         NYY
# 351     518626  0.233  .327  0.386  0.714   6      Donaldson, Josh         NYY
# 354     503556  0.244  .300  0.390  0.690   2     Gonzalez, Marwin         NYY
# 353     608336  0.180  .295  0.360  0.655   9          Gallo, Joey         NYY
# 358     643396  0.269  .322  0.321  0.643   0  Kiner-Falefa, Isiah         NYY
# 355     543305  0.232  .344  0.288  0.633   2         Hicks, Aaron         NYY
# 349     609280  0.268  .279  0.317  0.596   0      Andujar, Miguel         NYY
# 356     543309  0.176  .222  0.324  0.546   4     Higashioka, Kyle         NYY
# 352     664314  0.000  .083  0.000  0.083   0     Florial, Estevan         NYY
# 348     656061  0.000  .---  0.000  0.000   0        Abreu, Albert         NYY

# %%
from os import path
# import datetime
# year = datetime.date.today().year
# print(year)
DATA_DIR = "C:/Users/jake_/Desktop/baseball_etl/data"

# %%
# for df in [f'hitting_{year}', f'pitching_{year}', 'career_hitting', 'career_pitching']:
#     (df.to_csv(path.join(DATA_DIR, f'{df}.csv'), index=False))

# %%
# data_all = {
#     'data1': hitting_2020,
#     'data2': hitting_career,
#     'data3': pitching_2022,
#     'data4': pitching_career
# }

# %%
# for i in range(1, len(data_all) + 1):
#     data_i = data_all['data' + str(i)]
#     data_i.to_csv('data' + str(i) + '.csv')

# %% [markdown]
# ##### From here we can store them in a SQL Database, or as csv's or whatever. Note usually we *would* want to store this data, as opposed to treating mlb.com's API as our storage that we calll whenever we want to do some analysis.
#
# ##### First, it's faster. It's much more efficient to store data locally (or even get it directly from a database online) than it is to re-hit a networked API every time we need the data
#
# ##### Second, it's the polite thing to do. Hosting and maintaining an API costs money. It's usually not a big deal playing around with it or grabbing data occasionally, but we don't need to overload servers when we don't have to.
#
# ##### Finally, storing the data means you'd have it if anything ever happened to the API.

# %%
pitching_career.to_csv(path.join(DATA_DIR, f"mlb_pitching_career.csv"), index=False)

# %%
pitching_2022.to_csv(path.join(DATA_DIR, f"mlb_pitching_2022.csv"), index=False)

# %%
hitting_career.to_csv(path.join(DATA_DIR, f"mlb_hitting_career.csv"), index=False)

# %%
hitting_2022.to_csv(path.join(DATA_DIR, f"mlb_hitting_2022.csv"), index=False)
